# %% [markdown]
# <a href="https://colab.research.google.com/github/MatthewYancey/16-9GAN/blob/master/src/model_image_difference_003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 16:9 Generative Model
# This notebook takes images that are in a 4:3 aspect ratio and adds to the image to shift them to a 16:9 aspect ratio.
#
# This notebook also looks at a smaller image size.

# %% [markdown]
# ## Imports and Parameters

# %%
import shutil
import pandas as pd
import numpy as np
import glob
from PIL import Image
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter

import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset
import torchvision.utils as vutils

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# network parameters
BATCH_SIZE = 10
N_GPU = 1
N_WORKERS = 1
N_EPOCHS = 10
DATASET_SIZE = 24000
LEARNING_RATE = 0.01

# image
IMG_SIZE = 64
SINGLE_SIDE_BLACKOUT = int((IMG_SIZE * 0.25) / 2)

# directories
IMG_DIR = '/content/gdrive/My Drive/repos/16:9GAN/data_out/frames/'
LOG_DIR = '/content/gdrive/My Drive/repos/16:9GAN/data_out/logs/model_003/'

# testing index
testing_index = [1000]

# checkpoint type
CHECKPOINT_TYPE = 'none' # none or prev_checkpoint

# print out
print('Number of pixels cropped %d' % SINGLE_SIDE_BLACKOUT)
# Out:
# Number of pixels cropped 8

# %% [markdown]
# ## Data

# %%
img_list = glob.glob(IMG_DIR + '*/*.jpg')
img_list = img_list[:DATASET_SIZE]
print('Number of images: %d' % len(img_list))
# Out:
# Number of images: 24000

# %%
# a custom dataset class for reading in our images from the list
class ReadFromList(Dataset):

    def __init__(self, img_list, transform=None):
        self.img_list = img_list
        self.transform = transform

    def __len__(self):
        return len(self.img_list)

    def __getitem__(self, idx):
        image169 = Image.open(self.img_list[idx]).convert('RGB')

        if self.transform is not None:
            image169 = self.transform(image169)

        # makes a 4:3 image with zeroed out the sides
        image43 = image169.clone()
        for x in range(SINGLE_SIDE_BLACKOUT):
            for y in range(IMG_SIZE):
                for i in range(3):
                    image43[i][y][x] = -1 # left side
                    image43[i][y][IMG_SIZE - 1 - x] = -1 # right side

        return (image43, image169)

# %%
# makes the dataset and data loader
dataset_train = ReadFromList(img_list, transform=transforms.Compose([
                                    transforms.Resize((IMG_SIZE, IMG_SIZE)),                                 
                                    transforms.ToTensor(),
                                    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),])
                                    # transforms.RandomHorizontalFlip(p=0.5),
                                    # transforms.RandomVerticalFlip(p=0.5),
                                    # transforms.CenterCrop(IMG_SIZE),
                        )

dataloader_train = torch.utils.data.DataLoader(dataset_train, batch_size=BATCH_SIZE, shuffle=True, num_workers=N_WORKERS)
print('Size of training dataset: %d' % len(dataloader_train.dataset))
n_batches = len(dataloader_train.dataset) / BATCH_SIZE

dataset_test = torch.utils.data.Subset(dataset_train, testing_index)
dataloader_test = torch.utils.data.DataLoader(dataset_test, batch_size=BATCH_SIZE, shuffle=True, num_workers=N_WORKERS)
print('Size of testing dataset: %d' % len(dataloader_test.dataset))
# Out:
# Size of training dataset: 24000
# Size of testing dataset: 1

# %%
# Decide which device we want to run on
device = torch.device("cuda:0" if (torch.cuda.is_available() and N_GPU > 0) else "cpu")

# %% [markdown]
# ### Plot random images of 4:3 and 16:9

# %%
# Plot some training images
batch = next(iter(dataloader_train))
batch_input = batch[0]
batch_target = batch[1]

plt.figure(figsize=(15, 15))
plt.axis('off')
plt.title('Target Images')
plt.imshow(np.transpose(vutils.make_grid(batch_target.to(device)[:64], padding=2, normalize=True, nrow=5).cpu(),(1,2,0)))

plt.figure(figsize=(15, 15))
plt.axis('off')
plt.title('Input Images')
plt.imshow(np.transpose(vutils.make_grid(batch_input.to(device)[:64], padding=2, normalize=True, nrow=5).cpu(),(1,2,0)))

# %%
# Plot the image that will be logged to tensorboard
batch = next(iter(dataloader_test))
batch_input = batch[0]
batch_target = batch[1]

plt.figure(figsize=(7, 7))
plt.axis('off')
plt.title('Target Images')
plt.imshow(np.transpose(vutils.make_grid(batch_target.to(device)[:64], padding=2, normalize=True, nrow=4).cpu(),(1,2,0)))

# %% [markdown]
# ## Network

# %%
# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
class Generator(nn.Module):
    def __init__(self, ngpu):
        super(Generator, self).__init__()
        self.ngpu = ngpu

        # self.encode1 = nn.Conv2d(3, 64, 4, 2, 1, bias=False) # 128
        # self.encode2 = nn.Conv2d(64, 128, 4, 2, 1, bias=False) # 64
        self.encode3 = nn.Conv2d(3, 256, 4, 2, 1, bias=False) # 32      
        self.encode4 = nn.Conv2d(256, 512, 4, 2, 1, bias=False) # 16
        self.encode5 = nn.Conv2d(512, 1024, 4, 2, 1, bias=False) # 8
        self.encode6 = nn.Conv2d(1024, 2048, 4, 2, 1, bias=False)#  4
        self.encode7 = nn.Conv2d(2048, 4000, 4, 2, 1, bias=False) # 1

        self.decode1 = nn.ConvTranspose2d(4000, 2048, 4, 2, 1, bias=False) # 4
        self.decode2 = nn.ConvTranspose2d(2048, 1024, 4, 2, 1, bias=False) # 8
        self.decode3 = nn.ConvTranspose2d(1024, 512, 4, 2, 1, bias=False) # 16
        self.decode4 = nn.ConvTranspose2d(512, 256, 4, 2, 1, bias=False) # 32
        self.decode5 = nn.ConvTranspose2d(256, 3, 4, 2, 1, bias=False) # 64
        # self.decode6 = nn.ConvTranspose2d(128, 64, 4, 2, 1, bias=False) # 128
        # self.decode7 = nn.ConvTranspose2d(64, 3, 4, 2, 1, bias=False) # 256

        self.batch_norm3 = nn.BatchNorm2d(3)
        self.batch_norm64 = nn.BatchNorm2d(64)
        self.batch_norm128 = nn.BatchNorm2d(128)
        self.batch_norm256 = nn.BatchNorm2d(256)
        self.batch_norm512 = nn.BatchNorm2d(512)
        self.batch_norm1024 = nn.BatchNorm2d(1024)
        self.batch_norm2048 = nn.BatchNorm2d(2048)
        self.batch_norm4000 = nn.BatchNorm2d(4000)

        self.relu = nn.ReLU(True)
        self.tanh = nn.Tanh()

    def forward(self, x):
        # encoding
        # x = self.encode1(x) # output size 128
        # x = self.batch_norm64(x)
        # x = self.relu(x)

        # x = self.encode2(x) # output size 64
        # x = self.batch_norm128(x)
        # x = self.relu(x)

        x = self.encode3(x) # output size 32
        x = self.batch_norm256(x)
        x = self.relu(x)
        
        x = self.encode4(x) # output size 16
        x = self.batch_norm512(x)
        x = self.relu(x)

        x = self.encode5(x) # output size 8
        x = self.batch_norm1024(x)
        x = self.relu(x)

        x = self.encode6(x) # output size 4
        x = self.batch_norm2048(x)
        x = self.relu(x)

        # decoding
        x = self.decode2(x) # output size 8
        x = self.batch_norm1024(x)
        x = self.relu(x)        

        x = self.decode3(x) # output size 16
        x = self.batch_norm512(x)
        x = self.relu(x)        

        x = self.decode4(x) # output size 32
        x = self.batch_norm256(x)
        x = self.relu(x)        

        x = self.decode5(x) # output size 64
        x = self.batch_norm3(x)
        x = self.tanh(x)


        return x

# %%
gen = Generator(N_GPU).to(device)

# Handle multi-gpu if desired
if (device.type == 'cuda') and (N_GPU > 1):
    gen = nn.DataParallel(netG, list(range(N_GPU)))

gen.apply(weights_init)
# Out:
# Generator(
#   (encode3): Conv2d(3, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (encode4): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (encode5): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (encode6): Conv2d(1024, 2048, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (encode7): Conv2d(2048, 4000, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (decode1): ConvTranspose2d(4000, 2048, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (decode2): ConvTranspose2d(2048, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (decode3): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (decode4): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (decode5): ConvTranspose2d(256, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batch_norm3): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm64): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm128): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm256): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm512): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm1024): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm2048): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm4000): BatchNorm2d(4000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (tanh): Tanh()
# )

# %% [markdown]
# ### Loss Function and Optimizer

# %%
loss = nn.MSELoss()
optimizer = optim.SGD(gen.parameters(), lr=LEARNING_RATE, momentum=0.9)

# %% [markdown]
# ## Loads Checkpoints

# %%
if CHECKPOINT_TYPE == 'prev_checkpoint':
    # loads the model weights
    checkpoint = torch.load(LOG_DIR + 'checkpoint.pt')
    gen.load_state_dict(checkpoint['gen_state'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    print('Checkpoint Loaded')
    
    # loads the epoch counter
    with open(LOG_DIR + 'itercount.txt', 'r') as f:
        batch_counter = int(f.read())
    # moves it up one becuase it's currenlty at the last epoch we did
    batch_counter += 1

elif CHECKPOINT_TYPE == 'none':
    # remove all previous logs
    try:
        shutil.rmtree(LOG_DIR)
        print('Folders removed')
    except FileNotFoundError:
        print('No log folder found')

    batch_counter = 1

else:
    print('Failed to specify a type')
# Out:
# No log folder found

# %% [markdown]
# ### Testing Generator output

# %%
batch = next(iter(dataloader_train))
batch_input = batch[0].cuda()
gen_output = gen(batch_input)

plt.figure(figsize=(15, 15))
plt.axis('off')
plt.title('Target Images')
plt.imshow(np.transpose(vutils.make_grid(gen_output.to(device)[:64], padding=2, normalize=True, nrow=5).detach().cpu().numpy(), (1,2,0)))

# %% [markdown]
# ## Training

# %%
writer = SummaryWriter(LOG_DIR)

# trianing loop
for epoch in range(N_EPOCHS):

    running_loss = 0
    for i, data in enumerate(dataloader_train, 0):
        inputs, targets = data
        inputs = inputs.cuda()
        targets = targets.cuda()

        # reset the optimizer
        optimizer.zero_grad()
        
        # forward + backward + optimize
        outputs = gen(inputs)
        loss_value = loss(outputs, targets)
        loss_value.backward()
        optimizer.step()

        # print statistics
        running_loss += loss_value.item()
        if i % 10 == 9:
            print('[Epochs: %d/%d, Total Batches: %d, Images: %d/%d] loss: %.3f' % (epoch + 1, N_EPOCHS, batch_counter, i + 1, n_batches, running_loss / 9))
            running_loss = 0.0

            # saves loss to the tensorboard log    
            writer.add_scalar('Loss/Training', loss_value.item(), batch_counter)

            # saves a checkpoint        
            checkpoint = {'gen_state': gen.state_dict(), 'optimizer': optimizer.state_dict()}
            torch.save(checkpoint, LOG_DIR + 'checkpoint.pt')

            # Saves an image so we can view the progression
            test_inputs = next(iter(dataloader_test))[0]
            test_inputs = test_inputs.cuda()
            with torch.no_grad():
                output = gen(test_inputs)
            grid = torchvision.utils.make_grid(output, normalize=True)
            writer.add_image('image_epoch_%d' % batch_counter, grid)

            # saves the epoch counter
            with open(LOG_DIR + '/itercount.txt', 'w') as f:
                f.write(str(batch_counter))

            batch_counter += 1
        
writer.close()
# Out:
# [Epochs: 1/10, Total Batches: 1, Images: 10/2400] loss: 0.598
# [Epochs: 1/10, Total Batches: 2, Images: 20/2400] loss: 0.332
# [Epochs: 1/10, Total Batches: 3, Images: 30/2400] loss: 0.254
# [Epochs: 1/10, Total Batches: 4, Images: 40/2400] loss: 0.243
# [Epochs: 1/10, Total Batches: 5, Images: 50/2400] loss: 0.225
# [Epochs: 1/10, Total Batches: 6, Images: 60/2400] loss: 0.208
# [Epochs: 1/10, Total Batches: 7, Images: 70/2400] loss: 0.199
# [Epochs: 1/10, Total Batches: 8, Images: 80/2400] loss: 0.210
# [Epochs: 1/10, Total Batches: 9, Images: 90/2400] loss: 0.196
# [Epochs: 1/10, Total Batches: 10, Images: 100/2400] loss: 0.194
# [Epochs: 1/10, Total Batches: 11, Images: 110/2400] loss: 0.209
# [Epochs: 1/10, Total Batches: 12, Images: 120/2400] loss: 0.175
# [Epochs: 1/10, Total Batches: 13, Images: 130/2400] loss: 0.168
# [Epochs: 1/10, Total Batches: 14, Images: 140/2400] loss: 0.177
# [Epochs: 1/10, Total Batches: 15, Images: 150/2400] loss: 0.175
# [Epochs: 1/10, Total Batches: 16, Images: 160/2400] loss: 0.165
# [Epochs: 1/10, Total Batches: 17, Images: 170/2400] loss: 0.161
# [Epochs: 1/10, Total Batches: 18, Images: 180/2400] loss: 0.148
# [Epochs: 1/10, Total Batches: 19, Images: 190/2400] loss: 0.173
# [Epochs: 1/10, Total Batches: 20, Images: 200/2400] loss: 0.142
# [Epochs: 1/10, Total Batches: 21, Images: 210/2400] loss: 0.144
# [Epochs: 1/10, Total Batches: 22, Images: 220/2400] loss: 0.154
# [Epochs: 1/10, Total Batches: 23, Images: 230/2400] loss: 0.143
# [Epochs: 1/10, Total Batches: 24, Images: 240/2400] loss: 0.128
# [Epochs: 1/10, Total Batches: 25, Images: 250/2400] loss: 0.148
# [Epochs: 1/10, Total Batches: 26, Images: 260/2400] loss: 0.121
# [Epochs: 1/10, Total Batches: 27, Images: 270/2400] loss: 0.125
# [Epochs: 1/10, Total Batches: 28, Images: 280/2400] loss: 0.116
# [Epochs: 1/10, Total Batches: 29, Images: 290/2400] loss: 0.125
# [Epochs: 1/10, Total Batches: 30, Images: 300/2400] loss: 0.125
# [Epochs: 1/10, Total Batches: 31, Images: 310/2400] loss: 0.128
# [Epochs: 1/10, Total Batches: 32, Images: 320/2400] loss: 0.112
# [Epochs: 1/10, Total Batches: 33, Images: 330/2400] loss: 0.155
# [Epochs: 1/10, Total Batches: 34, Images: 340/2400] loss: 0.108
# [Epochs: 1/10, Total Batches: 35, Images: 350/2400] loss: 0.104
# [Epochs: 1/10, Total Batches: 36, Images: 360/2400] loss: 0.112
# [Epochs: 1/10, Total Batches: 37, Images: 370/2400] loss: 0.118
# [Epochs: 1/10, Total Batches: 38, Images: 380/2400] loss: 0.110
# [Epochs: 1/10, Total Batches: 39, Images: 390/2400] loss: 0.119
# [Epochs: 1/10, Total Batches: 40, Images: 400/2400] loss: 0.116
# [Epochs: 1/10, Total Batches: 41, Images: 410/2400] loss: 0.119
# [Epochs: 1/10, Total Batches: 42, Images: 420/2400] loss: 0.106
# [Epochs: 1/10, Total Batches: 43, Images: 430/2400] loss: 0.112
# [Epochs: 1/10, Total Batches: 44, Images: 440/2400] loss: 0.105
# [Epochs: 1/10, Total Batches: 45, Images: 450/2400] loss: 0.106
# [Epochs: 1/10, Total Batches: 46, Images: 460/2400] loss: 0.103
# [Epochs: 1/10, Total Batches: 47, Images: 470/2400] loss: 0.095
# [Epochs: 1/10, Total Batches: 48, Images: 480/2400] loss: 0.093
# [Epochs: 1/10, Total Batches: 49, Images: 490/2400] loss: 0.103
# [Epochs: 1/10, Total Batches: 50, Images: 500/2400] loss: 0.102
# [Epochs: 1/10, Total Batches: 51, Images: 510/2400] loss: 0.101
# [Epochs: 1/10, Total Batches: 52, Images: 520/2400] loss: 0.099
# [Epochs: 1/10, Total Batches: 53, Images: 530/2400] loss: 0.094
# [Epochs: 1/10, Total Batches: 54, Images: 540/2400] loss: 0.097
# [Epochs: 1/10, Total Batches: 55, Images: 550/2400] loss: 0.095
# [Epochs: 1/10, Total Batches: 56, Images: 560/2400] loss: 0.097
# [Epochs: 1/10, Total Batches: 57, Images: 570/2400] loss: 0.084
# [Epochs: 1/10, Total Batches: 58, Images: 580/2400] loss: 0.102
# [Epochs: 1/10, Total Batches: 59, Images: 590/2400] loss: 0.108
# [Epochs: 1/10, Total Batches: 60, Images: 600/2400] loss: 0.093
# [Epochs: 1/10, Total Batches: 61, Images: 610/2400] loss: 0.102
# [Epochs: 1/10, Total Batches: 62, Images: 620/2400] loss: 0.093
# [Epochs: 1/10, Total Batches: 63, Images: 630/2400] loss: 0.085
# [Epochs: 1/10, Total Batches: 64, Images: 640/2400] loss: 0.087
# [Epochs: 1/10, Total Batches: 65, Images: 650/2400] loss: 0.114
# [Epochs: 1/10, Total Batches: 66, Images: 660/2400] loss: 0.096
# [Epochs: 1/10, Total Batches: 67, Images: 670/2400] loss: 0.084
# [Epochs: 1/10, Total Batches: 68, Images: 680/2400] loss: 0.081
# [Epochs: 1/10, Total Batches: 69, Images: 690/2400] loss: 0.104
# [Epochs: 1/10, Total Batches: 70, Images: 700/2400] loss: 0.087
# [Epochs: 1/10, Total Batches: 71, Images: 710/2400] loss: 0.088
# [Epochs: 1/10, Total Batches: 72, Images: 720/2400] loss: 0.078
# [Epochs: 1/10, Total Batches: 73, Images: 730/2400] loss: 0.092
# [Epochs: 1/10, Total Batches: 74, Images: 740/2400] loss: 0.096
# [Epochs: 1/10, Total Batches: 75, Images: 750/2400] loss: 0.076
# [Epochs: 1/10, Total Batches: 76, Images: 760/2400] loss: 0.088
# [Epochs: 1/10, Total Batches: 77, Images: 770/2400] loss: 0.077
# [Epochs: 1/10, Total Batches: 78, Images: 780/2400] loss: 0.088
# [Epochs: 1/10, Total Batches: 79, Images: 790/2400] loss: 0.088
# [Epochs: 1/10, Total Batches: 80, Images: 800/2400] loss: 0.073
# [Epochs: 1/10, Total Batches: 81, Images: 810/2400] loss: 0.080
# [Epochs: 1/10, Total Batches: 82, Images: 820/2400] loss: 0.078
# [Epochs: 1/10, Total Batches: 83, Images: 830/2400] loss: 0.083
# [Epochs: 1/10, Total Batches: 84, Images: 840/2400] loss: 0.070
# [Epochs: 1/10, Total Batches: 85, Images: 850/2400] loss: 0.087
# [Epochs: 1/10, Total Batches: 86, Images: 860/2400] loss: 0.082
# [Epochs: 1/10, Total Batches: 87, Images: 870/2400] loss: 0.078
# [Epochs: 1/10, Total Batches: 88, Images: 880/2400] loss: 0.099
# [Epochs: 1/10, Total Batches: 89, Images: 890/2400] loss: 0.075
# [Epochs: 1/10, Total Batches: 90, Images: 900/2400] loss: 0.074
# [Epochs: 1/10, Total Batches: 91, Images: 910/2400] loss: 0.075
# [Epochs: 1/10, Total Batches: 92, Images: 920/2400] loss: 0.085
# [Epochs: 1/10, Total Batches: 93, Images: 930/2400] loss: 0.083
# [Epochs: 1/10, Total Batches: 94, Images: 940/2400] loss: 0.088
# [Epochs: 1/10, Total Batches: 95, Images: 950/2400] loss: 0.075
# [Epochs: 1/10, Total Batches: 96, Images: 960/2400] loss: 0.076
# [Epochs: 1/10, Total Batches: 97, Images: 970/2400] loss: 0.077
# [Epochs: 1/10, Total Batches: 98, Images: 980/2400] loss: 0.093
# [Epochs: 1/10, Total Batches: 99, Images: 990/2400] loss: 0.063
# [Epochs: 1/10, Total Batches: 100, Images: 1000/2400] loss: 0.079
# [Epochs: 1/10, Total Batches: 101, Images: 1010/2400] loss: 0.076
# [Epochs: 1/10, Total Batches: 102, Images: 1020/2400] loss: 0.074
# [Epochs: 1/10, Total Batches: 103, Images: 1030/2400] loss: 0.079
# [Epochs: 1/10, Total Batches: 104, Images: 1040/2400] loss: 0.079
# [Epochs: 1/10, Total Batches: 105, Images: 1050/2400] loss: 0.067
# [Epochs: 1/10, Total Batches: 106, Images: 1060/2400] loss: 0.073
# [Epochs: 1/10, Total Batches: 107, Images: 1070/2400] loss: 0.085
# [Epochs: 1/10, Total Batches: 108, Images: 1080/2400] loss: 0.068
# [Epochs: 1/10, Total Batches: 109, Images: 1090/2400] loss: 0.071
# [Epochs: 1/10, Total Batches: 110, Images: 1100/2400] loss: 0.081
# [Epochs: 1/10, Total Batches: 111, Images: 1110/2400] loss: 0.073
# [Epochs: 1/10, Total Batches: 112, Images: 1120/2400] loss: 0.074
# [Epochs: 1/10, Total Batches: 113, Images: 1130/2400] loss: 0.080
# [Epochs: 1/10, Total Batches: 114, Images: 1140/2400] loss: 0.070
# [Epochs: 1/10, Total Batches: 115, Images: 1150/2400] loss: 0.081
# [Epochs: 1/10, Total Batches: 116, Images: 1160/2400] loss: 0.066
# [Epochs: 1/10, Total Batches: 117, Images: 1170/2400] loss: 0.088
# [Epochs: 1/10, Total Batches: 118, Images: 1180/2400] loss: 0.067
# [Epochs: 1/10, Total Batches: 119, Images: 1190/2400] loss: 0.077
# [Epochs: 1/10, Total Batches: 120, Images: 1200/2400] loss: 0.064
# [Epochs: 1/10, Total Batches: 121, Images: 1210/2400] loss: 0.082
# [Epochs: 1/10, Total Batches: 122, Images: 1220/2400] loss: 0.062
# [Epochs: 1/10, Total Batches: 123, Images: 1230/2400] loss: 0.079
# [Epochs: 1/10, Total Batches: 124, Images: 1240/2400] loss: 0.065
# [Epochs: 1/10, Total Batches: 125, Images: 1250/2400] loss: 0.068
# [Epochs: 1/10, Total Batches: 126, Images: 1260/2400] loss: 0.066
# [Epochs: 1/10, Total Batches: 127, Images: 1270/2400] loss: 0.074
# [Epochs: 1/10, Total Batches: 128, Images: 1280/2400] loss: 0.066
# [Epochs: 1/10, Total Batches: 129, Images: 1290/2400] loss: 0.067
# [Epochs: 1/10, Total Batches: 130, Images: 1300/2400] loss: 0.075
# [Epochs: 1/10, Total Batches: 131, Images: 1310/2400] loss: 0.072
# [Epochs: 1/10, Total Batches: 132, Images: 1320/2400] loss: 0.063
# [Epochs: 1/10, Total Batches: 133, Images: 1330/2400] loss: 0.075
# [Epochs: 1/10, Total Batches: 134, Images: 1340/2400] loss: 0.073
# [Epochs: 1/10, Total Batches: 135, Images: 1350/2400] loss: 0.065
# [Epochs: 1/10, Total Batches: 136, Images: 1360/2400] loss: 0.059
# [Epochs: 1/10, Total Batches: 137, Images: 1370/2400] loss: 0.065
# [Epochs: 1/10, Total Batches: 138, Images: 1380/2400] loss: 0.067
# [Epochs: 1/10, Total Batches: 139, Images: 1390/2400] loss: 0.067
# [Epochs: 1/10, Total Batches: 140, Images: 1400/2400] loss: 0.072
# [Epochs: 1/10, Total Batches: 141, Images: 1410/2400] loss: 0.083
# [Epochs: 1/10, Total Batches: 142, Images: 1420/2400] loss: 0.075
# [Epochs: 1/10, Total Batches: 143, Images: 1430/2400] loss: 0.061
# [Epochs: 1/10, Total Batches: 144, Images: 1440/2400] loss: 0.078
# [Epochs: 1/10, Total Batches: 145, Images: 1450/2400] loss: 0.070
# [Epochs: 1/10, Total Batches: 146, Images: 1460/2400] loss: 0.068
# [Epochs: 1/10, Total Batches: 147, Images: 1470/2400] loss: 0.072
# [Epochs: 1/10, Total Batches: 148, Images: 1480/2400] loss: 0.062
# [Epochs: 1/10, Total Batches: 149, Images: 1490/2400] loss: 0.067
# [Epochs: 1/10, Total Batches: 150, Images: 1500/2400] loss: 0.076
# [Epochs: 1/10, Total Batches: 151, Images: 1510/2400] loss: 0.071
# [Epochs: 1/10, Total Batches: 152, Images: 1520/2400] loss: 0.067
# [Epochs: 1/10, Total Batches: 153, Images: 1530/2400] loss: 0.071
# [Epochs: 1/10, Total Batches: 154, Images: 1540/2400] loss: 0.062
# [Epochs: 1/10, Total Batches: 155, Images: 1550/2400] loss: 0.071
# [Epochs: 1/10, Total Batches: 156, Images: 1560/2400] loss: 0.078
# [Epochs: 1/10, Total Batches: 157, Images: 1570/2400] loss: 0.072
# [Epochs: 1/10, Total Batches: 158, Images: 1580/2400] loss: 0.059
# [Epochs: 1/10, Total Batches: 159, Images: 1590/2400] loss: 0.063
# [Epochs: 1/10, Total Batches: 160, Images: 1600/2400] loss: 0.078
# [Epochs: 1/10, Total Batches: 161, Images: 1610/2400] loss: 0.075
# [Epochs: 1/10, Total Batches: 162, Images: 1620/2400] loss: 0.072
# [Epochs: 1/10, Total Batches: 163, Images: 1630/2400] loss: 0.062
# [Epochs: 1/10, Total Batches: 164, Images: 1640/2400] loss: 0.074
# [Epochs: 1/10, Total Batches: 165, Images: 1650/2400] loss: 0.073
# [Epochs: 1/10, Total Batches: 166, Images: 1660/2400] loss: 0.084
# [Epochs: 1/10, Total Batches: 167, Images: 1670/2400] loss: 0.068
# [Epochs: 1/10, Total Batches: 168, Images: 1680/2400] loss: 0.061
# [Epochs: 1/10, Total Batches: 169, Images: 1690/2400] loss: 0.067
# [Epochs: 1/10, Total Batches: 170, Images: 1700/2400] loss: 0.067
# [Epochs: 1/10, Total Batches: 171, Images: 1710/2400] loss: 0.059
# [Epochs: 1/10, Total Batches: 172, Images: 1720/2400] loss: 0.064
# [Epochs: 1/10, Total Batches: 173, Images: 1730/2400] loss: 0.063
# [Epochs: 1/10, Total Batches: 174, Images: 1740/2400] loss: 0.075
# [Epochs: 1/10, Total Batches: 175, Images: 1750/2400] loss: 0.069
# [Epochs: 1/10, Total Batches: 176, Images: 1760/2400] loss: 0.074
# [Epochs: 1/10, Total Batches: 177, Images: 1770/2400] loss: 0.069
# [Epochs: 1/10, Total Batches: 178, Images: 1780/2400] loss: 0.064
# [Epochs: 1/10, Total Batches: 179, Images: 1790/2400] loss: 0.067
# [Epochs: 1/10, Total Batches: 180, Images: 1800/2400] loss: 0.066
# [Epochs: 1/10, Total Batches: 181, Images: 1810/2400] loss: 0.066
# [Epochs: 1/10, Total Batches: 182, Images: 1820/2400] loss: 0.075
# [Epochs: 1/10, Total Batches: 183, Images: 1830/2400] loss: 0.074
# [Epochs: 1/10, Total Batches: 184, Images: 1840/2400] loss: 0.062
# [Epochs: 1/10, Total Batches: 185, Images: 1850/2400] loss: 0.059
# [Epochs: 1/10, Total Batches: 186, Images: 1860/2400] loss: 0.076
# [Epochs: 1/10, Total Batches: 187, Images: 1870/2400] loss: 0.058
# [Epochs: 1/10, Total Batches: 188, Images: 1880/2400] loss: 0.070
# [Epochs: 1/10, Total Batches: 189, Images: 1890/2400] loss: 0.071
# [Epochs: 1/10, Total Batches: 190, Images: 1900/2400] loss: 0.074
# [Epochs: 1/10, Total Batches: 191, Images: 1910/2400] loss: 0.060
# [Epochs: 1/10, Total Batches: 192, Images: 1920/2400] loss: 0.064
# [Epochs: 1/10, Total Batches: 193, Images: 1930/2400] loss: 0.056
# [Epochs: 1/10, Total Batches: 194, Images: 1940/2400] loss: 0.065
# [Epochs: 1/10, Total Batches: 195, Images: 1950/2400] loss: 0.066
# [Epochs: 1/10, Total Batches: 196, Images: 1960/2400] loss: 0.062
# [Epochs: 1/10, Total Batches: 197, Images: 1970/2400] loss: 0.071
# [Epochs: 1/10, Total Batches: 198, Images: 1980/2400] loss: 0.072
# [Epochs: 1/10, Total Batches: 199, Images: 1990/2400] loss: 0.064
# [Epochs: 1/10, Total Batches: 200, Images: 2000/2400] loss: 0.072
# [Epochs: 1/10, Total Batches: 201, Images: 2010/2400] loss: 0.062
# [Epochs: 1/10, Total Batches: 202, Images: 2020/2400] loss: 0.059
# [Epochs: 1/10, Total Batches: 203, Images: 2030/2400] loss: 0.073
# [Epochs: 1/10, Total Batches: 204, Images: 2040/2400] loss: 0.063
# [Epochs: 1/10, Total Batches: 205, Images: 2050/2400] loss: 0.068
# [Epochs: 1/10, Total Batches: 206, Images: 2060/2400] loss: 0.074
# [Epochs: 1/10, Total Batches: 207, Images: 2070/2400] loss: 0.077
# [Epochs: 1/10, Total Batches: 208, Images: 2080/2400] loss: 0.051
# [Epochs: 1/10, Total Batches: 209, Images: 2090/2400] loss: 0.070
# [Epochs: 1/10, Total Batches: 210, Images: 2100/2400] loss: 0.066
# [Epochs: 1/10, Total Batches: 211, Images: 2110/2400] loss: 0.081
# [Epochs: 1/10, Total Batches: 212, Images: 2120/2400] loss: 0.068
# [Epochs: 1/10, Total Batches: 213, Images: 2130/2400] loss: 0.068
# [Epochs: 1/10, Total Batches: 214, Images: 2140/2400] loss: 0.062
# [Epochs: 1/10, Total Batches: 215, Images: 2150/2400] loss: 0.071
# [Epochs: 1/10, Total Batches: 216, Images: 2160/2400] loss: 0.064
# [Epochs: 1/10, Total Batches: 217, Images: 2170/2400] loss: 0.062
# [Epochs: 1/10, Total Batches: 218, Images: 2180/2400] loss: 0.054
# [Epochs: 1/10, Total Batches: 219, Images: 2190/2400] loss: 0.067
# [Epochs: 1/10, Total Batches: 220, Images: 2200/2400] loss: 0.062
# [Epochs: 1/10, Total Batches: 221, Images: 2210/2400] loss: 0.058
# [Epochs: 1/10, Total Batches: 222, Images: 2220/2400] loss: 0.054
# [Epochs: 1/10, Total Batches: 223, Images: 2230/2400] loss: 0.072
# [Epochs: 1/10, Total Batches: 224, Images: 2240/2400] loss: 0.072
# [Epochs: 1/10, Total Batches: 225, Images: 2250/2400] loss: 0.058
# [Epochs: 1/10, Total Batches: 226, Images: 2260/2400] loss: 0.055
# [Epochs: 1/10, Total Batches: 227, Images: 2270/2400] loss: 0.074
# [Epochs: 1/10, Total Batches: 228, Images: 2280/2400] loss: 0.058
# [Epochs: 1/10, Total Batches: 229, Images: 2290/2400] loss: 0.072
# [Epochs: 1/10, Total Batches: 230, Images: 2300/2400] loss: 0.060
# [Epochs: 1/10, Total Batches: 231, Images: 2310/2400] loss: 0.069
# [Epochs: 1/10, Total Batches: 232, Images: 2320/2400] loss: 0.065
# [Epochs: 1/10, Total Batches: 233, Images: 2330/2400] loss: 0.064
# [Epochs: 1/10, Total Batches: 234, Images: 2340/2400] loss: 0.085
# [Epochs: 1/10, Total Batches: 235, Images: 2350/2400] loss: 0.061
# [Epochs: 1/10, Total Batches: 236, Images: 2360/2400] loss: 0.061
# [Epochs: 1/10, Total Batches: 237, Images: 2370/2400] loss: 0.061
# [Epochs: 1/10, Total Batches: 238, Images: 2380/2400] loss: 0.054
# [Epochs: 1/10, Total Batches: 239, Images: 2390/2400] loss: 0.072
# [Epochs: 1/10, Total Batches: 240, Images: 2400/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 241, Images: 10/2400] loss: 0.060
# [Epochs: 2/10, Total Batches: 242, Images: 20/2400] loss: 0.060
# [Epochs: 2/10, Total Batches: 243, Images: 30/2400] loss: 0.065
# [Epochs: 2/10, Total Batches: 244, Images: 40/2400] loss: 0.057
# [Epochs: 2/10, Total Batches: 245, Images: 50/2400] loss: 0.063
# [Epochs: 2/10, Total Batches: 246, Images: 60/2400] loss: 0.068
# [Epochs: 2/10, Total Batches: 247, Images: 70/2400] loss: 0.060
# [Epochs: 2/10, Total Batches: 248, Images: 80/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 249, Images: 90/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 250, Images: 100/2400] loss: 0.053
# [Epochs: 2/10, Total Batches: 251, Images: 110/2400] loss: 0.064
# [Epochs: 2/10, Total Batches: 252, Images: 120/2400] loss: 0.060
# [Epochs: 2/10, Total Batches: 253, Images: 130/2400] loss: 0.072
# [Epochs: 2/10, Total Batches: 254, Images: 140/2400] loss: 0.062
# [Epochs: 2/10, Total Batches: 255, Images: 150/2400] loss: 0.058
# [Epochs: 2/10, Total Batches: 256, Images: 160/2400] loss: 0.078
# [Epochs: 2/10, Total Batches: 257, Images: 170/2400] loss: 0.060
# [Epochs: 2/10, Total Batches: 258, Images: 180/2400] loss: 0.057
# [Epochs: 2/10, Total Batches: 259, Images: 190/2400] loss: 0.065
# [Epochs: 2/10, Total Batches: 260, Images: 200/2400] loss: 0.063
# [Epochs: 2/10, Total Batches: 261, Images: 210/2400] loss: 0.058
# [Epochs: 2/10, Total Batches: 262, Images: 220/2400] loss: 0.055
# [Epochs: 2/10, Total Batches: 263, Images: 230/2400] loss: 0.051
# [Epochs: 2/10, Total Batches: 264, Images: 240/2400] loss: 0.077
# [Epochs: 2/10, Total Batches: 265, Images: 250/2400] loss: 0.051
# [Epochs: 2/10, Total Batches: 266, Images: 260/2400] loss: 0.057
# [Epochs: 2/10, Total Batches: 267, Images: 270/2400] loss: 0.058
# [Epochs: 2/10, Total Batches: 268, Images: 280/2400] loss: 0.070
# [Epochs: 2/10, Total Batches: 269, Images: 290/2400] loss: 0.055
# [Epochs: 2/10, Total Batches: 270, Images: 300/2400] loss: 0.054
# [Epochs: 2/10, Total Batches: 271, Images: 310/2400] loss: 0.064
# [Epochs: 2/10, Total Batches: 272, Images: 320/2400] loss: 0.058
# [Epochs: 2/10, Total Batches: 273, Images: 330/2400] loss: 0.056
# [Epochs: 2/10, Total Batches: 274, Images: 340/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 275, Images: 350/2400] loss: 0.051
# [Epochs: 2/10, Total Batches: 276, Images: 360/2400] loss: 0.057
# [Epochs: 2/10, Total Batches: 277, Images: 370/2400] loss: 0.060
# [Epochs: 2/10, Total Batches: 278, Images: 380/2400] loss: 0.062
# [Epochs: 2/10, Total Batches: 279, Images: 390/2400] loss: 0.064
# [Epochs: 2/10, Total Batches: 280, Images: 400/2400] loss: 0.064
# [Epochs: 2/10, Total Batches: 281, Images: 410/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 282, Images: 420/2400] loss: 0.075
# [Epochs: 2/10, Total Batches: 283, Images: 430/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 284, Images: 440/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 285, Images: 450/2400] loss: 0.070
# [Epochs: 2/10, Total Batches: 286, Images: 460/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 287, Images: 470/2400] loss: 0.066
# [Epochs: 2/10, Total Batches: 288, Images: 480/2400] loss: 0.060
# [Epochs: 2/10, Total Batches: 289, Images: 490/2400] loss: 0.054
# [Epochs: 2/10, Total Batches: 290, Images: 500/2400] loss: 0.069
# [Epochs: 2/10, Total Batches: 291, Images: 510/2400] loss: 0.055
# [Epochs: 2/10, Total Batches: 292, Images: 520/2400] loss: 0.060
# [Epochs: 2/10, Total Batches: 293, Images: 530/2400] loss: 0.063
# [Epochs: 2/10, Total Batches: 294, Images: 540/2400] loss: 0.058
# [Epochs: 2/10, Total Batches: 295, Images: 550/2400] loss: 0.050
# [Epochs: 2/10, Total Batches: 296, Images: 560/2400] loss: 0.055
# [Epochs: 2/10, Total Batches: 297, Images: 570/2400] loss: 0.049
# [Epochs: 2/10, Total Batches: 298, Images: 580/2400] loss: 0.064
# [Epochs: 2/10, Total Batches: 299, Images: 590/2400] loss: 0.050
# [Epochs: 2/10, Total Batches: 300, Images: 600/2400] loss: 0.054
# [Epochs: 2/10, Total Batches: 301, Images: 610/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 302, Images: 620/2400] loss: 0.057
# [Epochs: 2/10, Total Batches: 303, Images: 630/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 304, Images: 640/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 305, Images: 650/2400] loss: 0.056
# [Epochs: 2/10, Total Batches: 306, Images: 660/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 307, Images: 670/2400] loss: 0.051
# [Epochs: 2/10, Total Batches: 308, Images: 680/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 309, Images: 690/2400] loss: 0.055
# [Epochs: 2/10, Total Batches: 310, Images: 700/2400] loss: 0.056
# [Epochs: 2/10, Total Batches: 311, Images: 710/2400] loss: 0.049
# [Epochs: 2/10, Total Batches: 312, Images: 720/2400] loss: 0.066
# [Epochs: 2/10, Total Batches: 313, Images: 730/2400] loss: 0.053
# [Epochs: 2/10, Total Batches: 314, Images: 740/2400] loss: 0.050
# [Epochs: 2/10, Total Batches: 315, Images: 750/2400] loss: 0.051
# [Epochs: 2/10, Total Batches: 316, Images: 760/2400] loss: 0.066
# [Epochs: 2/10, Total Batches: 317, Images: 770/2400] loss: 0.056
# [Epochs: 2/10, Total Batches: 318, Images: 780/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 319, Images: 790/2400] loss: 0.057
# [Epochs: 2/10, Total Batches: 320, Images: 800/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 321, Images: 810/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 322, Images: 820/2400] loss: 0.049
# [Epochs: 2/10, Total Batches: 323, Images: 830/2400] loss: 0.056
# [Epochs: 2/10, Total Batches: 324, Images: 840/2400] loss: 0.064
# [Epochs: 2/10, Total Batches: 325, Images: 850/2400] loss: 0.055
# [Epochs: 2/10, Total Batches: 326, Images: 860/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 327, Images: 870/2400] loss: 0.056
# [Epochs: 2/10, Total Batches: 328, Images: 880/2400] loss: 0.065
# [Epochs: 2/10, Total Batches: 329, Images: 890/2400] loss: 0.064
# [Epochs: 2/10, Total Batches: 330, Images: 900/2400] loss: 0.063
# [Epochs: 2/10, Total Batches: 331, Images: 910/2400] loss: 0.053
# [Epochs: 2/10, Total Batches: 332, Images: 920/2400] loss: 0.066
# [Epochs: 2/10, Total Batches: 333, Images: 930/2400] loss: 0.063
# [Epochs: 2/10, Total Batches: 334, Images: 940/2400] loss: 0.058
# [Epochs: 2/10, Total Batches: 335, Images: 950/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 336, Images: 960/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 337, Images: 970/2400] loss: 0.070
# [Epochs: 2/10, Total Batches: 338, Images: 980/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 339, Images: 990/2400] loss: 0.066
# [Epochs: 2/10, Total Batches: 340, Images: 1000/2400] loss: 0.058
# [Epochs: 2/10, Total Batches: 341, Images: 1010/2400] loss: 0.053
# [Epochs: 2/10, Total Batches: 342, Images: 1020/2400] loss: 0.051
# [Epochs: 2/10, Total Batches: 343, Images: 1030/2400] loss: 0.054
# [Epochs: 2/10, Total Batches: 344, Images: 1040/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 345, Images: 1050/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 346, Images: 1060/2400] loss: 0.057
# [Epochs: 2/10, Total Batches: 347, Images: 1070/2400] loss: 0.058
# [Epochs: 2/10, Total Batches: 348, Images: 1080/2400] loss: 0.073
# [Epochs: 2/10, Total Batches: 349, Images: 1090/2400] loss: 0.065
# [Epochs: 2/10, Total Batches: 350, Images: 1100/2400] loss: 0.052
# [Epochs: 2/10, Total Batches: 351, Images: 1110/2400] loss: 0.057
# [Epochs: 2/10, Total Batches: 352, Images: 1120/2400] loss: 0.051
# [Epochs: 2/10, Total Batches: 353, Images: 1130/2400] loss: 0.053
# [Epochs: 2/10, Total Batches: 354, Images: 1140/2400] loss: 0.052
# [Epochs: 2/10, Total Batches: 355, Images: 1150/2400] loss: 0.050
# [Epochs: 2/10, Total Batches: 356, Images: 1160/2400] loss: 0.049
# [Epochs: 2/10, Total Batches: 357, Images: 1170/2400] loss: 0.057
# [Epochs: 2/10, Total Batches: 358, Images: 1180/2400] loss: 0.050
# [Epochs: 2/10, Total Batches: 359, Images: 1190/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 360, Images: 1200/2400] loss: 0.065
# [Epochs: 2/10, Total Batches: 361, Images: 1210/2400] loss: 0.047
# [Epochs: 2/10, Total Batches: 362, Images: 1220/2400] loss: 0.062
# [Epochs: 2/10, Total Batches: 363, Images: 1230/2400] loss: 0.080
# [Epochs: 2/10, Total Batches: 364, Images: 1240/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 365, Images: 1250/2400] loss: 0.073
# [Epochs: 2/10, Total Batches: 366, Images: 1260/2400] loss: 0.054
# [Epochs: 2/10, Total Batches: 367, Images: 1270/2400] loss: 0.057
# [Epochs: 2/10, Total Batches: 368, Images: 1280/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 369, Images: 1290/2400] loss: 0.057
# [Epochs: 2/10, Total Batches: 370, Images: 1300/2400] loss: 0.075
# [Epochs: 2/10, Total Batches: 371, Images: 1310/2400] loss: 0.069
# [Epochs: 2/10, Total Batches: 372, Images: 1320/2400] loss: 0.058
# [Epochs: 2/10, Total Batches: 373, Images: 1330/2400] loss: 0.062
# [Epochs: 2/10, Total Batches: 374, Images: 1340/2400] loss: 0.068
# [Epochs: 2/10, Total Batches: 375, Images: 1350/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 376, Images: 1360/2400] loss: 0.050
# [Epochs: 2/10, Total Batches: 377, Images: 1370/2400] loss: 0.057
# [Epochs: 2/10, Total Batches: 378, Images: 1380/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 379, Images: 1390/2400] loss: 0.060
# [Epochs: 2/10, Total Batches: 380, Images: 1400/2400] loss: 0.058
# [Epochs: 2/10, Total Batches: 381, Images: 1410/2400] loss: 0.060
# [Epochs: 2/10, Total Batches: 382, Images: 1420/2400] loss: 0.052
# [Epochs: 2/10, Total Batches: 383, Images: 1430/2400] loss: 0.054
# [Epochs: 2/10, Total Batches: 384, Images: 1440/2400] loss: 0.049
# [Epochs: 2/10, Total Batches: 385, Images: 1450/2400] loss: 0.052
# [Epochs: 2/10, Total Batches: 386, Images: 1460/2400] loss: 0.067
# [Epochs: 2/10, Total Batches: 387, Images: 1470/2400] loss: 0.055
# [Epochs: 2/10, Total Batches: 388, Images: 1480/2400] loss: 0.055
# [Epochs: 2/10, Total Batches: 389, Images: 1490/2400] loss: 0.066
# [Epochs: 2/10, Total Batches: 390, Images: 1500/2400] loss: 0.053
# [Epochs: 2/10, Total Batches: 391, Images: 1510/2400] loss: 0.049
# [Epochs: 2/10, Total Batches: 392, Images: 1520/2400] loss: 0.053
# [Epochs: 2/10, Total Batches: 393, Images: 1530/2400] loss: 0.044
# [Epochs: 2/10, Total Batches: 394, Images: 1540/2400] loss: 0.058
# [Epochs: 2/10, Total Batches: 395, Images: 1550/2400] loss: 0.055
# [Epochs: 2/10, Total Batches: 396, Images: 1560/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 397, Images: 1570/2400] loss: 0.049
# [Epochs: 2/10, Total Batches: 398, Images: 1580/2400] loss: 0.053
# [Epochs: 2/10, Total Batches: 399, Images: 1590/2400] loss: 0.067
# [Epochs: 2/10, Total Batches: 400, Images: 1600/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 401, Images: 1610/2400] loss: 0.048
# [Epochs: 2/10, Total Batches: 402, Images: 1620/2400] loss: 0.051
# [Epochs: 2/10, Total Batches: 403, Images: 1630/2400] loss: 0.053
# [Epochs: 2/10, Total Batches: 404, Images: 1640/2400] loss: 0.052
# [Epochs: 2/10, Total Batches: 405, Images: 1650/2400] loss: 0.051
# [Epochs: 2/10, Total Batches: 406, Images: 1660/2400] loss: 0.070
# [Epochs: 2/10, Total Batches: 407, Images: 1670/2400] loss: 0.050
# [Epochs: 2/10, Total Batches: 408, Images: 1680/2400] loss: 0.060
# [Epochs: 2/10, Total Batches: 409, Images: 1690/2400] loss: 0.057
# [Epochs: 2/10, Total Batches: 410, Images: 1700/2400] loss: 0.056
# [Epochs: 2/10, Total Batches: 411, Images: 1710/2400] loss: 0.058
# [Epochs: 2/10, Total Batches: 412, Images: 1720/2400] loss: 0.058
# [Epochs: 2/10, Total Batches: 413, Images: 1730/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 414, Images: 1740/2400] loss: 0.055
# [Epochs: 2/10, Total Batches: 415, Images: 1750/2400] loss: 0.048
# [Epochs: 2/10, Total Batches: 416, Images: 1760/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 417, Images: 1770/2400] loss: 0.047
# [Epochs: 2/10, Total Batches: 418, Images: 1780/2400] loss: 0.070
# [Epochs: 2/10, Total Batches: 419, Images: 1790/2400] loss: 0.051
# [Epochs: 2/10, Total Batches: 420, Images: 1800/2400] loss: 0.055
# [Epochs: 2/10, Total Batches: 421, Images: 1810/2400] loss: 0.046
# [Epochs: 2/10, Total Batches: 422, Images: 1820/2400] loss: 0.067
# [Epochs: 2/10, Total Batches: 423, Images: 1830/2400] loss: 0.051
# [Epochs: 2/10, Total Batches: 424, Images: 1840/2400] loss: 0.064
# [Epochs: 2/10, Total Batches: 425, Images: 1850/2400] loss: 0.056
# [Epochs: 2/10, Total Batches: 426, Images: 1860/2400] loss: 0.044
# [Epochs: 2/10, Total Batches: 427, Images: 1870/2400] loss: 0.047
# [Epochs: 2/10, Total Batches: 428, Images: 1880/2400] loss: 0.060
# [Epochs: 2/10, Total Batches: 429, Images: 1890/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 430, Images: 1900/2400] loss: 0.057
# [Epochs: 2/10, Total Batches: 431, Images: 1910/2400] loss: 0.055
# [Epochs: 2/10, Total Batches: 432, Images: 1920/2400] loss: 0.062
# [Epochs: 2/10, Total Batches: 433, Images: 1930/2400] loss: 0.051
# [Epochs: 2/10, Total Batches: 434, Images: 1940/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 435, Images: 1950/2400] loss: 0.054
# [Epochs: 2/10, Total Batches: 436, Images: 1960/2400] loss: 0.056
# [Epochs: 2/10, Total Batches: 437, Images: 1970/2400] loss: 0.063
# [Epochs: 2/10, Total Batches: 438, Images: 1980/2400] loss: 0.056
# [Epochs: 2/10, Total Batches: 439, Images: 1990/2400] loss: 0.051
# [Epochs: 2/10, Total Batches: 440, Images: 2000/2400] loss: 0.058
# [Epochs: 2/10, Total Batches: 441, Images: 2010/2400] loss: 0.057
# [Epochs: 2/10, Total Batches: 442, Images: 2020/2400] loss: 0.050
# [Epochs: 2/10, Total Batches: 443, Images: 2030/2400] loss: 0.069
# [Epochs: 2/10, Total Batches: 444, Images: 2040/2400] loss: 0.063
# [Epochs: 2/10, Total Batches: 445, Images: 2050/2400] loss: 0.064
# [Epochs: 2/10, Total Batches: 446, Images: 2060/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 447, Images: 2070/2400] loss: 0.057
# [Epochs: 2/10, Total Batches: 448, Images: 2080/2400] loss: 0.052
# [Epochs: 2/10, Total Batches: 449, Images: 2090/2400] loss: 0.048
# [Epochs: 2/10, Total Batches: 450, Images: 2100/2400] loss: 0.046
# [Epochs: 2/10, Total Batches: 451, Images: 2110/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 452, Images: 2120/2400] loss: 0.065
# [Epochs: 2/10, Total Batches: 453, Images: 2130/2400] loss: 0.053
# [Epochs: 2/10, Total Batches: 454, Images: 2140/2400] loss: 0.056
# [Epochs: 2/10, Total Batches: 455, Images: 2150/2400] loss: 0.052
# [Epochs: 2/10, Total Batches: 456, Images: 2160/2400] loss: 0.052
# [Epochs: 2/10, Total Batches: 457, Images: 2170/2400] loss: 0.056
# [Epochs: 2/10, Total Batches: 458, Images: 2180/2400] loss: 0.057
# [Epochs: 2/10, Total Batches: 459, Images: 2190/2400] loss: 0.062
# [Epochs: 2/10, Total Batches: 460, Images: 2200/2400] loss: 0.048
# [Epochs: 2/10, Total Batches: 461, Images: 2210/2400] loss: 0.047
# [Epochs: 2/10, Total Batches: 462, Images: 2220/2400] loss: 0.052
# [Epochs: 2/10, Total Batches: 463, Images: 2230/2400] loss: 0.052
# [Epochs: 2/10, Total Batches: 464, Images: 2240/2400] loss: 0.060
# [Epochs: 2/10, Total Batches: 465, Images: 2250/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 466, Images: 2260/2400] loss: 0.053
# [Epochs: 2/10, Total Batches: 467, Images: 2270/2400] loss: 0.053
# [Epochs: 2/10, Total Batches: 468, Images: 2280/2400] loss: 0.060
# [Epochs: 2/10, Total Batches: 469, Images: 2290/2400] loss: 0.056
# [Epochs: 2/10, Total Batches: 470, Images: 2300/2400] loss: 0.067
# [Epochs: 2/10, Total Batches: 471, Images: 2310/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 472, Images: 2320/2400] loss: 0.054
# [Epochs: 2/10, Total Batches: 473, Images: 2330/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 474, Images: 2340/2400] loss: 0.061
# [Epochs: 2/10, Total Batches: 475, Images: 2350/2400] loss: 0.065
# [Epochs: 2/10, Total Batches: 476, Images: 2360/2400] loss: 0.053
# [Epochs: 2/10, Total Batches: 477, Images: 2370/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 478, Images: 2380/2400] loss: 0.059
# [Epochs: 2/10, Total Batches: 479, Images: 2390/2400] loss: 0.055
# [Epochs: 2/10, Total Batches: 480, Images: 2400/2400] loss: 0.056
# [Epochs: 3/10, Total Batches: 481, Images: 10/2400] loss: 0.055
# [Epochs: 3/10, Total Batches: 482, Images: 20/2400] loss: 0.048
# [Epochs: 3/10, Total Batches: 483, Images: 30/2400] loss: 0.053
# [Epochs: 3/10, Total Batches: 484, Images: 40/2400] loss: 0.056
# [Epochs: 3/10, Total Batches: 485, Images: 50/2400] loss: 0.055
# [Epochs: 3/10, Total Batches: 486, Images: 60/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 487, Images: 70/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 488, Images: 80/2400] loss: 0.051
# [Epochs: 3/10, Total Batches: 489, Images: 90/2400] loss: 0.059
# [Epochs: 3/10, Total Batches: 490, Images: 100/2400] loss: 0.057
# [Epochs: 3/10, Total Batches: 491, Images: 110/2400] loss: 0.053
# [Epochs: 3/10, Total Batches: 492, Images: 120/2400] loss: 0.057
# [Epochs: 3/10, Total Batches: 493, Images: 130/2400] loss: 0.054
# [Epochs: 3/10, Total Batches: 494, Images: 140/2400] loss: 0.054
# [Epochs: 3/10, Total Batches: 495, Images: 150/2400] loss: 0.047
# [Epochs: 3/10, Total Batches: 496, Images: 160/2400] loss: 0.054
# [Epochs: 3/10, Total Batches: 497, Images: 170/2400] loss: 0.051
# [Epochs: 3/10, Total Batches: 498, Images: 180/2400] loss: 0.056
# [Epochs: 3/10, Total Batches: 499, Images: 190/2400] loss: 0.057
# [Epochs: 3/10, Total Batches: 500, Images: 200/2400] loss: 0.057
# [Epochs: 3/10, Total Batches: 501, Images: 210/2400] loss: 0.056
# [Epochs: 3/10, Total Batches: 502, Images: 220/2400] loss: 0.046
# [Epochs: 3/10, Total Batches: 503, Images: 230/2400] loss: 0.053
# [Epochs: 3/10, Total Batches: 504, Images: 240/2400] loss: 0.056
# [Epochs: 3/10, Total Batches: 505, Images: 250/2400] loss: 0.051
# [Epochs: 3/10, Total Batches: 506, Images: 260/2400] loss: 0.044
# [Epochs: 3/10, Total Batches: 507, Images: 270/2400] loss: 0.053
# [Epochs: 3/10, Total Batches: 508, Images: 280/2400] loss: 0.054
# [Epochs: 3/10, Total Batches: 509, Images: 290/2400] loss: 0.077
# [Epochs: 3/10, Total Batches: 510, Images: 300/2400] loss: 0.053
# [Epochs: 3/10, Total Batches: 511, Images: 310/2400] loss: 0.046
# [Epochs: 3/10, Total Batches: 512, Images: 320/2400] loss: 0.056
# [Epochs: 3/10, Total Batches: 513, Images: 330/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 514, Images: 340/2400] loss: 0.052
# [Epochs: 3/10, Total Batches: 515, Images: 350/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 516, Images: 360/2400] loss: 0.065
# [Epochs: 3/10, Total Batches: 517, Images: 370/2400] loss: 0.054
# [Epochs: 3/10, Total Batches: 518, Images: 380/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 519, Images: 390/2400] loss: 0.044
# [Epochs: 3/10, Total Batches: 520, Images: 400/2400] loss: 0.051
# [Epochs: 3/10, Total Batches: 521, Images: 410/2400] loss: 0.077
# [Epochs: 3/10, Total Batches: 522, Images: 420/2400] loss: 0.053
# [Epochs: 3/10, Total Batches: 523, Images: 430/2400] loss: 0.056
# [Epochs: 3/10, Total Batches: 524, Images: 440/2400] loss: 0.054
# [Epochs: 3/10, Total Batches: 525, Images: 450/2400] loss: 0.047
# [Epochs: 3/10, Total Batches: 526, Images: 460/2400] loss: 0.062
# [Epochs: 3/10, Total Batches: 527, Images: 470/2400] loss: 0.060
# [Epochs: 3/10, Total Batches: 528, Images: 480/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 529, Images: 490/2400] loss: 0.042
# [Epochs: 3/10, Total Batches: 530, Images: 500/2400] loss: 0.057
# [Epochs: 3/10, Total Batches: 531, Images: 510/2400] loss: 0.047
# [Epochs: 3/10, Total Batches: 532, Images: 520/2400] loss: 0.047
# [Epochs: 3/10, Total Batches: 533, Images: 530/2400] loss: 0.053
# [Epochs: 3/10, Total Batches: 534, Images: 540/2400] loss: 0.051
# [Epochs: 3/10, Total Batches: 535, Images: 550/2400] loss: 0.056
# [Epochs: 3/10, Total Batches: 536, Images: 560/2400] loss: 0.058
# [Epochs: 3/10, Total Batches: 537, Images: 570/2400] loss: 0.051
# [Epochs: 3/10, Total Batches: 538, Images: 580/2400] loss: 0.059
# [Epochs: 3/10, Total Batches: 539, Images: 590/2400] loss: 0.059
# [Epochs: 3/10, Total Batches: 540, Images: 600/2400] loss: 0.045
# [Epochs: 3/10, Total Batches: 541, Images: 610/2400] loss: 0.052
# [Epochs: 3/10, Total Batches: 542, Images: 620/2400] loss: 0.055
# [Epochs: 3/10, Total Batches: 543, Images: 630/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 544, Images: 640/2400] loss: 0.048
# [Epochs: 3/10, Total Batches: 545, Images: 650/2400] loss: 0.048
# [Epochs: 3/10, Total Batches: 546, Images: 660/2400] loss: 0.054
# [Epochs: 3/10, Total Batches: 547, Images: 670/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 548, Images: 680/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 549, Images: 690/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 550, Images: 700/2400] loss: 0.042
# [Epochs: 3/10, Total Batches: 551, Images: 710/2400] loss: 0.056
# [Epochs: 3/10, Total Batches: 552, Images: 720/2400] loss: 0.056
# [Epochs: 3/10, Total Batches: 553, Images: 730/2400] loss: 0.047
# [Epochs: 3/10, Total Batches: 554, Images: 740/2400] loss: 0.060
# [Epochs: 3/10, Total Batches: 555, Images: 750/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 556, Images: 760/2400] loss: 0.052
# [Epochs: 3/10, Total Batches: 557, Images: 770/2400] loss: 0.048
# [Epochs: 3/10, Total Batches: 558, Images: 780/2400] loss: 0.047
# [Epochs: 3/10, Total Batches: 559, Images: 790/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 560, Images: 800/2400] loss: 0.046
# [Epochs: 3/10, Total Batches: 561, Images: 810/2400] loss: 0.054
# [Epochs: 3/10, Total Batches: 562, Images: 820/2400] loss: 0.048
# [Epochs: 3/10, Total Batches: 563, Images: 830/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 564, Images: 840/2400] loss: 0.051
# [Epochs: 3/10, Total Batches: 565, Images: 850/2400] loss: 0.040
# [Epochs: 3/10, Total Batches: 566, Images: 860/2400] loss: 0.051
# [Epochs: 3/10, Total Batches: 567, Images: 870/2400] loss: 0.053
# [Epochs: 3/10, Total Batches: 568, Images: 880/2400] loss: 0.046
# [Epochs: 3/10, Total Batches: 569, Images: 890/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 570, Images: 900/2400] loss: 0.061
# [Epochs: 3/10, Total Batches: 571, Images: 910/2400] loss: 0.047
# [Epochs: 3/10, Total Batches: 572, Images: 920/2400] loss: 0.051
# [Epochs: 3/10, Total Batches: 573, Images: 930/2400] loss: 0.044
# [Epochs: 3/10, Total Batches: 574, Images: 940/2400] loss: 0.057
# [Epochs: 3/10, Total Batches: 575, Images: 950/2400] loss: 0.056
# [Epochs: 3/10, Total Batches: 576, Images: 960/2400] loss: 0.053
# [Epochs: 3/10, Total Batches: 577, Images: 970/2400] loss: 0.055
# [Epochs: 3/10, Total Batches: 578, Images: 980/2400] loss: 0.046
# [Epochs: 3/10, Total Batches: 579, Images: 990/2400] loss: 0.046
# [Epochs: 3/10, Total Batches: 580, Images: 1000/2400] loss: 0.059
# [Epochs: 3/10, Total Batches: 581, Images: 1010/2400] loss: 0.055
# [Epochs: 3/10, Total Batches: 582, Images: 1020/2400] loss: 0.047
# [Epochs: 3/10, Total Batches: 583, Images: 1030/2400] loss: 0.052
# [Epochs: 3/10, Total Batches: 584, Images: 1040/2400] loss: 0.046
# [Epochs: 3/10, Total Batches: 585, Images: 1050/2400] loss: 0.044
# [Epochs: 3/10, Total Batches: 586, Images: 1060/2400] loss: 0.052
# [Epochs: 3/10, Total Batches: 587, Images: 1070/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 588, Images: 1080/2400] loss: 0.052
# [Epochs: 3/10, Total Batches: 589, Images: 1090/2400] loss: 0.059
# [Epochs: 3/10, Total Batches: 590, Images: 1100/2400] loss: 0.047
# [Epochs: 3/10, Total Batches: 591, Images: 1110/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 592, Images: 1120/2400] loss: 0.044
# [Epochs: 3/10, Total Batches: 593, Images: 1130/2400] loss: 0.053
# [Epochs: 3/10, Total Batches: 594, Images: 1140/2400] loss: 0.046
# [Epochs: 3/10, Total Batches: 595, Images: 1150/2400] loss: 0.057
# [Epochs: 3/10, Total Batches: 596, Images: 1160/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 597, Images: 1170/2400] loss: 0.059
# [Epochs: 3/10, Total Batches: 598, Images: 1180/2400] loss: 0.044
# [Epochs: 3/10, Total Batches: 599, Images: 1190/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 600, Images: 1200/2400] loss: 0.051
# [Epochs: 3/10, Total Batches: 601, Images: 1210/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 602, Images: 1220/2400] loss: 0.048
# [Epochs: 3/10, Total Batches: 603, Images: 1230/2400] loss: 0.057
# [Epochs: 3/10, Total Batches: 604, Images: 1240/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 605, Images: 1250/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 606, Images: 1260/2400] loss: 0.052
# [Epochs: 3/10, Total Batches: 607, Images: 1270/2400] loss: 0.048
# [Epochs: 3/10, Total Batches: 608, Images: 1280/2400] loss: 0.053
# [Epochs: 3/10, Total Batches: 609, Images: 1290/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 610, Images: 1300/2400] loss: 0.067
# [Epochs: 3/10, Total Batches: 611, Images: 1310/2400] loss: 0.052
# [Epochs: 3/10, Total Batches: 612, Images: 1320/2400] loss: 0.040
# [Epochs: 3/10, Total Batches: 613, Images: 1330/2400] loss: 0.048
# [Epochs: 3/10, Total Batches: 614, Images: 1340/2400] loss: 0.043
# [Epochs: 3/10, Total Batches: 615, Images: 1350/2400] loss: 0.043
# [Epochs: 3/10, Total Batches: 616, Images: 1360/2400] loss: 0.041
# [Epochs: 3/10, Total Batches: 617, Images: 1370/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 618, Images: 1380/2400] loss: 0.048
# [Epochs: 3/10, Total Batches: 619, Images: 1390/2400] loss: 0.054
# [Epochs: 3/10, Total Batches: 620, Images: 1400/2400] loss: 0.057
# [Epochs: 3/10, Total Batches: 621, Images: 1410/2400] loss: 0.055
# [Epochs: 3/10, Total Batches: 622, Images: 1420/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 623, Images: 1430/2400] loss: 0.053
# [Epochs: 3/10, Total Batches: 624, Images: 1440/2400] loss: 0.047
# [Epochs: 3/10, Total Batches: 625, Images: 1450/2400] loss: 0.047
# [Epochs: 3/10, Total Batches: 626, Images: 1460/2400] loss: 0.046
# [Epochs: 3/10, Total Batches: 627, Images: 1470/2400] loss: 0.048
# [Epochs: 3/10, Total Batches: 628, Images: 1480/2400] loss: 0.056
# [Epochs: 3/10, Total Batches: 629, Images: 1490/2400] loss: 0.048
# [Epochs: 3/10, Total Batches: 630, Images: 1500/2400] loss: 0.054
# [Epochs: 3/10, Total Batches: 631, Images: 1510/2400] loss: 0.046
# [Epochs: 3/10, Total Batches: 632, Images: 1520/2400] loss: 0.044
# [Epochs: 3/10, Total Batches: 633, Images: 1530/2400] loss: 0.043
# [Epochs: 3/10, Total Batches: 634, Images: 1540/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 635, Images: 1550/2400] loss: 0.055
# [Epochs: 3/10, Total Batches: 636, Images: 1560/2400] loss: 0.044
# [Epochs: 3/10, Total Batches: 637, Images: 1570/2400] loss: 0.055
# [Epochs: 3/10, Total Batches: 638, Images: 1580/2400] loss: 0.048
# [Epochs: 3/10, Total Batches: 639, Images: 1590/2400] loss: 0.053
# [Epochs: 3/10, Total Batches: 640, Images: 1600/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 641, Images: 1610/2400] loss: 0.052
# [Epochs: 3/10, Total Batches: 642, Images: 1620/2400] loss: 0.044
# [Epochs: 3/10, Total Batches: 643, Images: 1630/2400] loss: 0.052
# [Epochs: 3/10, Total Batches: 644, Images: 1640/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 645, Images: 1650/2400] loss: 0.053
# [Epochs: 3/10, Total Batches: 646, Images: 1660/2400] loss: 0.053
# [Epochs: 3/10, Total Batches: 647, Images: 1670/2400] loss: 0.045
# [Epochs: 3/10, Total Batches: 648, Images: 1680/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 649, Images: 1690/2400] loss: 0.059
# [Epochs: 3/10, Total Batches: 650, Images: 1700/2400] loss: 0.056
# [Epochs: 3/10, Total Batches: 651, Images: 1710/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 652, Images: 1720/2400] loss: 0.056
# [Epochs: 3/10, Total Batches: 653, Images: 1730/2400] loss: 0.051
# [Epochs: 3/10, Total Batches: 654, Images: 1740/2400] loss: 0.045
# [Epochs: 3/10, Total Batches: 655, Images: 1750/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 656, Images: 1760/2400] loss: 0.048
# [Epochs: 3/10, Total Batches: 657, Images: 1770/2400] loss: 0.053
# [Epochs: 3/10, Total Batches: 658, Images: 1780/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 659, Images: 1790/2400] loss: 0.046
# [Epochs: 3/10, Total Batches: 660, Images: 1800/2400] loss: 0.044
# [Epochs: 3/10, Total Batches: 661, Images: 1810/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 662, Images: 1820/2400] loss: 0.055
# [Epochs: 3/10, Total Batches: 663, Images: 1830/2400] loss: 0.058
# [Epochs: 3/10, Total Batches: 664, Images: 1840/2400] loss: 0.041
# [Epochs: 3/10, Total Batches: 665, Images: 1850/2400] loss: 0.046
# [Epochs: 3/10, Total Batches: 666, Images: 1860/2400] loss: 0.046
# [Epochs: 3/10, Total Batches: 667, Images: 1870/2400] loss: 0.052
# [Epochs: 3/10, Total Batches: 668, Images: 1880/2400] loss: 0.044
# [Epochs: 3/10, Total Batches: 669, Images: 1890/2400] loss: 0.052
# [Epochs: 3/10, Total Batches: 670, Images: 1900/2400] loss: 0.051
# [Epochs: 3/10, Total Batches: 671, Images: 1910/2400] loss: 0.046
# [Epochs: 3/10, Total Batches: 672, Images: 1920/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 673, Images: 1930/2400] loss: 0.052
# [Epochs: 3/10, Total Batches: 674, Images: 1940/2400] loss: 0.051
# [Epochs: 3/10, Total Batches: 675, Images: 1950/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 676, Images: 1960/2400] loss: 0.044
# [Epochs: 3/10, Total Batches: 677, Images: 1970/2400] loss: 0.048
# [Epochs: 3/10, Total Batches: 678, Images: 1980/2400] loss: 0.048
# [Epochs: 3/10, Total Batches: 679, Images: 1990/2400] loss: 0.044
# [Epochs: 3/10, Total Batches: 680, Images: 2000/2400] loss: 0.043
# [Epochs: 3/10, Total Batches: 681, Images: 2010/2400] loss: 0.051
# [Epochs: 3/10, Total Batches: 682, Images: 2020/2400] loss: 0.048
# [Epochs: 3/10, Total Batches: 683, Images: 2030/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 684, Images: 2040/2400] loss: 0.055
# [Epochs: 3/10, Total Batches: 685, Images: 2050/2400] loss: 0.046
# [Epochs: 3/10, Total Batches: 686, Images: 2060/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 687, Images: 2070/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 688, Images: 2080/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 689, Images: 2090/2400] loss: 0.055
# [Epochs: 3/10, Total Batches: 690, Images: 2100/2400] loss: 0.053
# [Epochs: 3/10, Total Batches: 691, Images: 2110/2400] loss: 0.046
# [Epochs: 3/10, Total Batches: 692, Images: 2120/2400] loss: 0.060
# [Epochs: 3/10, Total Batches: 693, Images: 2130/2400] loss: 0.044
# [Epochs: 3/10, Total Batches: 694, Images: 2140/2400] loss: 0.045
# [Epochs: 3/10, Total Batches: 695, Images: 2150/2400] loss: 0.046
# [Epochs: 3/10, Total Batches: 696, Images: 2160/2400] loss: 0.052
# [Epochs: 3/10, Total Batches: 697, Images: 2170/2400] loss: 0.044
# [Epochs: 3/10, Total Batches: 698, Images: 2180/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 699, Images: 2190/2400] loss: 0.052
# [Epochs: 3/10, Total Batches: 700, Images: 2200/2400] loss: 0.054
# [Epochs: 3/10, Total Batches: 701, Images: 2210/2400] loss: 0.055
# [Epochs: 3/10, Total Batches: 702, Images: 2220/2400] loss: 0.061
# [Epochs: 3/10, Total Batches: 703, Images: 2230/2400] loss: 0.048
# [Epochs: 3/10, Total Batches: 704, Images: 2240/2400] loss: 0.047
# [Epochs: 3/10, Total Batches: 705, Images: 2250/2400] loss: 0.051
# [Epochs: 3/10, Total Batches: 706, Images: 2260/2400] loss: 0.062
# [Epochs: 3/10, Total Batches: 707, Images: 2270/2400] loss: 0.056
# [Epochs: 3/10, Total Batches: 708, Images: 2280/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 709, Images: 2290/2400] loss: 0.045
# [Epochs: 3/10, Total Batches: 710, Images: 2300/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 711, Images: 2310/2400] loss: 0.056
# [Epochs: 3/10, Total Batches: 712, Images: 2320/2400] loss: 0.060
# [Epochs: 3/10, Total Batches: 713, Images: 2330/2400] loss: 0.044
# [Epochs: 3/10, Total Batches: 714, Images: 2340/2400] loss: 0.049
# [Epochs: 3/10, Total Batches: 715, Images: 2350/2400] loss: 0.050
# [Epochs: 3/10, Total Batches: 716, Images: 2360/2400] loss: 0.041
# [Epochs: 3/10, Total Batches: 717, Images: 2370/2400] loss: 0.057
# [Epochs: 3/10, Total Batches: 718, Images: 2380/2400] loss: 0.043
# [Epochs: 3/10, Total Batches: 719, Images: 2390/2400] loss: 0.047
# [Epochs: 3/10, Total Batches: 720, Images: 2400/2400] loss: 0.044
# [Epochs: 4/10, Total Batches: 721, Images: 10/2400] loss: 0.049
# [Epochs: 4/10, Total Batches: 722, Images: 20/2400] loss: 0.041
