# %% [markdown]
# <a href="https://colab.research.google.com/github/MatthewYancey/16-9GAN/blob/master/model_image_difference_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 16:9 Generative Model
# This notebook takes images that are in a 4:3 aspect ratio and adds to the image to shift them to a 16:9 aspect ratio.

# %% [markdown]
# ## Imports and Parameters

# %%
import shutil
import pandas as pd
import numpy as np
import glob
from PIL import Image
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter

import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset
import torchvision.utils as vutils

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# network parameters
BATCH_SIZE = 10
N_GPU = 1
N_WORKERS = 1
N_EPOCHS = 10
DATASET_SIZE = 24000

# image
IMG_SIZE = 256
SINGLE_SIDE_BLACKOUT = 32

# directories
IMG_DIR = '/content/gdrive/My Drive/repos/16:9GAN/data_out/frames/'
LOG_DIR = '/content/gdrive/My Drive/repos/16:9GAN/data_out/logs/model_001/'

# testing index
testing_index = [1000]

# checkpoint type
CHECKPOINT_TYPE = 'none' # none or prev_checkpoint

# %% [markdown]
# ## Data

# %%
img_list = glob.glob(IMG_DIR + '*/*.jpg')
img_list = img_list[:DATASET_SIZE]
print('Number of images: %d' % len(img_list))
# Out:
# Number of images: 22071

# %%
# a custom dataset class for reading in our images from the list
class ReadFromList(Dataset):

    def __init__(self, img_list, transform=None):
        self.img_list = img_list
        self.transform = transform

    def __len__(self):
        return len(self.img_list)

    def __getitem__(self, idx):
        image169 = Image.open(self.img_list[idx]).convert('RGB')


        if self.transform is not None:
            image169 = self.transform(image169)

        # zeros out the sides of the 16:9 image to get a 4:3
        image43 = image169.clone()
        for x in range(SINGLE_SIDE_BLACKOUT):
            for y in range(IMG_SIZE):
                for i in range(3):
                    image43[i][y][x] = -1
                    image43[i][y][IMG_SIZE - 1 - x] = -1

        return (image43, image169)

# %%
# makes the dataset and data loader
dataset_train = ReadFromList(img_list, transform=transforms.Compose([
                                    # transforms.RandomHorizontalFlip(p=0.5),
                                    # transforms.RandomVerticalFlip(p=0.5),
                                    # transforms.CenterCrop(IMG_SIZE),
                                    transforms.ToTensor(),
                                    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),])
                        )

dataloader_train = torch.utils.data.DataLoader(dataset_train, batch_size=BATCH_SIZE, shuffle=True, num_workers=N_WORKERS)
print('Size of training dataset: %d' % len(dataloader_train.dataset))
n_batches = len(dataloader_train.dataset) / BATCH_SIZE

dataset_test = torch.utils.data.Subset(dataset_train, testing_index)
dataloader_test = torch.utils.data.DataLoader(dataset_test, batch_size=BATCH_SIZE, shuffle=True, num_workers=N_WORKERS)
print('Size of testing dataset: %d' % len(dataloader_test.dataset))
# Out:
# Size of training dataset: 22071
# Size of testing dataset: 1

# %%
# Decide which device we want to run on
device = torch.device("cuda:0" if (torch.cuda.is_available() and N_GPU > 0) else "cpu")

# %% [markdown]
# ### Plot random images of 4:3 and 16:9

# %%
# Plot some training images
batch = next(iter(dataloader_train))
batch_input = batch[0]
batch_target = batch[1]

plt.figure(figsize=(15, 15))
plt.axis('off')
plt.title('Target Images')
plt.imshow(np.transpose(vutils.make_grid(batch_target.to(device)[:64], padding=2, normalize=True, nrow=5).cpu(),(1,2,0)))

plt.figure(figsize=(15, 15))
plt.axis('off')
plt.title('Input Images')
plt.imshow(np.transpose(vutils.make_grid(batch_input.to(device)[:64], padding=2, normalize=True, nrow=5).cpu(),(1,2,0)))

# %%
# Plot the image that will be logged to tensorboard
batch = next(iter(dataloader_test))
batch_input = batch[0]
batch_target = batch[1]

plt.figure(figsize=(15, 15))
plt.axis('off')
plt.title('Target Images')
plt.imshow(np.transpose(vutils.make_grid(batch_target.to(device)[:64], padding=2, normalize=True, nrow=4).cpu(),(1,2,0)))

# %% [markdown]
# ## Network

# %%
# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
class Generator(nn.Module):
    def __init__(self, ngpu):
        super(Generator, self).__init__()
        self.ngpu = ngpu

        self.encode1 = nn.Conv2d(3, 64, 4, 2, 1, bias=False) # 128
        self.encode2 = nn.Conv2d(64, 128, 4, 2, 1, bias=False) # 64
        self.encode3 = nn.Conv2d(128, 256, 4, 2, 1, bias=False) # 32      
        self.encode4 = nn.Conv2d(256, 512, 4, 2, 1, bias=False) # 16
        self.encode5 = nn.Conv2d(512, 1024, 4, 2, 1, bias=False) # 8
        self.encode6 = nn.Conv2d(1024, 2048, 4, 2, 1, bias=False)#  4

        self.decode1 = nn.ConvTranspose2d(4000, 2048, 4, 2, 1, bias=False) # 4
        self.decode2 = nn.ConvTranspose2d(2048, 1024, 4, 2, 1, bias=False) # 8
        self.decode3 = nn.ConvTranspose2d(1024, 512, 4, 2, 1, bias=False) # 16
        self.decode4 = nn.ConvTranspose2d(512, 256, 4, 2, 1, bias=False) # 32
        self.decode5 = nn.ConvTranspose2d(256, 128, 4, 2, 1, bias=False) # 64
        self.decode6 = nn.ConvTranspose2d(128, 64, 4, 2, 1, bias=False) # 128
        self.decode7 = nn.ConvTranspose2d(64, 3, 4, 2, 1, bias=False) # 256

        self.batch_norm3 = nn.BatchNorm2d(3)
        self.batch_norm64 = nn.BatchNorm2d(64)
        self.batch_norm128 = nn.BatchNorm2d(128)
        self.batch_norm256 = nn.BatchNorm2d(256)
        self.batch_norm512 = nn.BatchNorm2d(512)
        self.batch_norm1024 = nn.BatchNorm2d(1024)
        self.batch_norm2048 = nn.BatchNorm2d(2048)

        self.relu = nn.ReLU(True)
        self.tanh = nn.Tanh()

    def forward(self, x):
        # encoding
        x = self.encode1(x) # output size 128
        x = self.batch_norm64(x)
        x = self.relu(x)

        x = self.encode2(x) # output size 64
        x = self.batch_norm128(x)
        x = self.relu(x)

        x = self.encode3(x) # output size 32
        x = self.batch_norm256(x)
        x = self.relu(x)
        
        x = self.encode4(x) # output size 16
        x = self.batch_norm512(x)
        x = self.relu(x)

        x = self.encode5(x) # output size 8
        x = self.batch_norm1024(x)
        x = self.relu(x)

        x = self.encode6(x) # output size 4
        x = self.batch_norm2048(x)
        x = self.relu(x)

        # decoding
        x = self.decode2(x) # output size 8
        x = self.batch_norm1024(x)
        x = self.relu(x)        

        x = self.decode3(x) # output size 16
        x = self.batch_norm512(x)
        x = self.relu(x)        

        x = self.decode4(x) # output size 32
        x = self.batch_norm256(x)
        x = self.relu(x)        

        x = self.decode5(x) # output size 64
        x = self.batch_norm128(x)
        x = self.relu(x)        

        x = self.decode6(x) # output size 128
        x = self.batch_norm64(x)
        x = self.relu(x)

        x = self.decode7(x) # output size 256
        x = self.batch_norm3(x)
        x = self.tanh(x)


        return x

# %%
gen = Generator(N_GPU).to(device)

# Handle multi-gpu if desired
if (device.type == 'cuda') and (N_GPU > 1):
    gen = nn.DataParallel(netG, list(range(N_GPU)))

gen.apply(weights_init)
# Out:
# Generator(
#   (encode1): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (encode2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (encode3): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (encode4): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (encode5): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (encode6): Conv2d(1024, 2048, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (decode1): ConvTranspose2d(4000, 2048, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (decode2): ConvTranspose2d(2048, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (decode3): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (decode4): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (decode5): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (decode6): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (decode7): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batch_norm3): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm64): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm128): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm256): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm512): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm1024): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm2048): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (tanh): Tanh()
# )

# %% [markdown]
# ### Loss Function and Optimizer

# %%
loss = nn.MSELoss()
optimizer = optim.SGD(gen.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# ## Loads Checkpoints

# %%
if CHECKPOINT_TYPE == 'prev_checkpoint':
    # loads the model weights
    checkpoint = torch.load(LOG_DIR + 'checkpoint.pt')
    gen.load_state_dict(checkpoint['gen_state'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    print('Checkpoint Loaded')
    
    # loads the epoch counter
    with open(LOG_DIR + 'itercount.txt', 'r') as f:
        batch_counter = int(f.read())
    # moves it up one becuase it's currenlty at the last epoch we did
    batch_counter += 1

elif CHECKPOINT_TYPE == 'none':
    # remove all previous logs
    try:
        shutil.rmtree(LOG_DIR)
        print('Folders removed')
    except FileNotFoundError:
        print('No log folder found')

    batch_counter = 1

else:
    print('Failed to specify a type')
# Out:
# No log folder found

# %% [markdown]
# ### Testing Generator output

# %%
batch = next(iter(dataloader_train))
batch_input = batch[0].cuda()
gen_output = gen(batch_input)

plt.figure(figsize=(15, 15))
plt.axis('off')
plt.title('Target Images')
plt.imshow(np.transpose(vutils.make_grid(gen_output.to(device)[:64], padding=2, normalize=True, nrow=5).detach().cpu().numpy(), (1,2,0)))

# %% [markdown]
# ## Training

# %%
writer = SummaryWriter(LOG_DIR)

# trianing loop
for epoch in range(N_EPOCHS):

    running_loss = 0
    for i, data in enumerate(dataloader_train, 0):
        inputs, targets = data
        inputs = inputs.cuda()
        targets = targets.cuda()

        # reset the optimizer
        optimizer.zero_grad()
        
        # forward + backward + optimize
        outputs = gen(inputs)
        loss_value = loss(outputs, targets)
        loss_value.backward()
        optimizer.step()

        # print statistics
        running_loss += loss_value.item()
        if i % 10 == 9:
            print('[Epochs: %d/%d, Total Batches: %d, Images: %d/%d] loss: %.3f' % (epoch + 1, N_EPOCHS, batch_counter, i + 1, n_batches, running_loss / 9))
            running_loss = 0.0

            # saves loss to the tensorboard log    
            writer.add_scalar('Loss/Training', loss_value.item(), batch_counter)

            # saves a checkpoint        
            checkpoint = {'gen_state': gen.state_dict(), 'optimizer': optimizer.state_dict()}
            torch.save(checkpoint, LOG_DIR + 'checkpoint.pt')

            # Saves an image so we can view the progression
            test_inputs = next(iter(dataloader_test))[0]
            test_inputs = test_inputs.cuda()
            with torch.no_grad():
                output = gen(test_inputs)
            grid = torchvision.utils.make_grid(output, normalize=True)
            writer.add_image('image_epoch_%d' % batch_counter, grid)

            writer.flush()

            # saves the epoch counter
            with open(LOG_DIR + '/itercount.txt', 'w') as f:
                f.write(str(batch_counter))

            batch_counter += 1

writer.close()
# Out:
# [Epochs: 1/10, Total Batches: 1, Images: 10/2207] loss: 0.738
# [Epochs: 1/10, Total Batches: 2, Images: 20/2207] loss: 0.658
# [Epochs: 1/10, Total Batches: 3, Images: 30/2207] loss: 0.531
# [Epochs: 1/10, Total Batches: 4, Images: 40/2207] loss: 0.413
# [Epochs: 1/10, Total Batches: 5, Images: 50/2207] loss: 0.365
# [Epochs: 1/10, Total Batches: 6, Images: 60/2207] loss: 0.342
# [Epochs: 1/10, Total Batches: 7, Images: 70/2207] loss: 0.345
# [Epochs: 1/10, Total Batches: 8, Images: 80/2207] loss: 0.364
# [Epochs: 1/10, Total Batches: 9, Images: 90/2207] loss: 0.332
# [Epochs: 1/10, Total Batches: 10, Images: 100/2207] loss: 0.332
# [Epochs: 1/10, Total Batches: 11, Images: 110/2207] loss: 0.300
# [Epochs: 1/10, Total Batches: 12, Images: 120/2207] loss: 0.300
# [Epochs: 1/10, Total Batches: 13, Images: 130/2207] loss: 0.303
# [Epochs: 1/10, Total Batches: 14, Images: 140/2207] loss: 0.278
# [Epochs: 1/10, Total Batches: 15, Images: 150/2207] loss: 0.301
# [Epochs: 1/10, Total Batches: 16, Images: 160/2207] loss: 0.255
# [Epochs: 1/10, Total Batches: 17, Images: 170/2207] loss: 0.321
# [Epochs: 1/10, Total Batches: 18, Images: 180/2207] loss: 0.296
# [Epochs: 1/10, Total Batches: 19, Images: 190/2207] loss: 0.282
# [Epochs: 1/10, Total Batches: 20, Images: 200/2207] loss: 0.274
# [Epochs: 1/10, Total Batches: 21, Images: 210/2207] loss: 0.271
# [Epochs: 1/10, Total Batches: 22, Images: 220/2207] loss: 0.292
# [Epochs: 1/10, Total Batches: 23, Images: 230/2207] loss: 0.265
# [Epochs: 1/10, Total Batches: 24, Images: 240/2207] loss: 0.248
# [Epochs: 1/10, Total Batches: 25, Images: 250/2207] loss: 0.251
# [Epochs: 1/10, Total Batches: 26, Images: 260/2207] loss: 0.294
# [Epochs: 1/10, Total Batches: 27, Images: 270/2207] loss: 0.275
# [Epochs: 1/10, Total Batches: 28, Images: 280/2207] loss: 0.258
# [Epochs: 1/10, Total Batches: 29, Images: 290/2207] loss: 0.266
# [Epochs: 1/10, Total Batches: 30, Images: 300/2207] loss: 0.281
# [Epochs: 1/10, Total Batches: 31, Images: 310/2207] loss: 0.278
# [Epochs: 1/10, Total Batches: 32, Images: 320/2207] loss: 0.265
# [Epochs: 1/10, Total Batches: 33, Images: 330/2207] loss: 0.277
# [Epochs: 1/10, Total Batches: 34, Images: 340/2207] loss: 0.242
# [Epochs: 1/10, Total Batches: 35, Images: 350/2207] loss: 0.289
# [Epochs: 1/10, Total Batches: 36, Images: 360/2207] loss: 0.254
# [Epochs: 1/10, Total Batches: 37, Images: 370/2207] loss: 0.256
# [Epochs: 1/10, Total Batches: 38, Images: 380/2207] loss: 0.266
# [Epochs: 1/10, Total Batches: 39, Images: 390/2207] loss: 0.273
# [Epochs: 1/10, Total Batches: 40, Images: 400/2207] loss: 0.260
# [Epochs: 1/10, Total Batches: 41, Images: 410/2207] loss: 0.259
# [Epochs: 1/10, Total Batches: 42, Images: 420/2207] loss: 0.249
# [Epochs: 1/10, Total Batches: 43, Images: 430/2207] loss: 0.245
# [Epochs: 1/10, Total Batches: 44, Images: 440/2207] loss: 0.264
# [Epochs: 1/10, Total Batches: 45, Images: 450/2207] loss: 0.236
# [Epochs: 1/10, Total Batches: 46, Images: 460/2207] loss: 0.269
# [Epochs: 1/10, Total Batches: 47, Images: 470/2207] loss: 0.238
# [Epochs: 1/10, Total Batches: 48, Images: 480/2207] loss: 0.250
# [Epochs: 1/10, Total Batches: 49, Images: 490/2207] loss: 0.240
# [Epochs: 1/10, Total Batches: 50, Images: 500/2207] loss: 0.244
# [Epochs: 1/10, Total Batches: 52, Images: 520/2207] loss: 0.233
# [Epochs: 1/10, Total Batches: 53, Images: 530/2207] loss: 0.245
# [Epochs: 1/10, Total Batches: 54, Images: 540/2207] loss: 0.260
# [Epochs: 1/10, Total Batches: 55, Images: 550/2207] loss: 0.261
# [Epochs: 1/10, Total Batches: 56, Images: 560/2207] loss: 0.229
# [Epochs: 1/10, Total Batches: 57, Images: 570/2207] loss: 0.238
# [Epochs: 1/10, Total Batches: 58, Images: 580/2207] loss: 0.252
# [Epochs: 1/10, Total Batches: 59, Images: 590/2207] loss: 0.247
# [Epochs: 1/10, Total Batches: 60, Images: 600/2207] loss: 0.260
# [Epochs: 1/10, Total Batches: 61, Images: 610/2207] loss: 0.244
# [Epochs: 1/10, Total Batches: 62, Images: 620/2207] loss: 0.252
# [Epochs: 1/10, Total Batches: 63, Images: 630/2207] loss: 0.257
# [Epochs: 1/10, Total Batches: 64, Images: 640/2207] loss: 0.247
# [Epochs: 1/10, Total Batches: 65, Images: 650/2207] loss: 0.222
# [Epochs: 1/10, Total Batches: 66, Images: 660/2207] loss: 0.254
# [Epochs: 1/10, Total Batches: 67, Images: 670/2207] loss: 0.266
# [Epochs: 1/10, Total Batches: 68, Images: 680/2207] loss: 0.234
# [Epochs: 1/10, Total Batches: 69, Images: 690/2207] loss: 0.249
# [Epochs: 1/10, Total Batches: 70, Images: 700/2207] loss: 0.214
# [Epochs: 1/10, Total Batches: 71, Images: 710/2207] loss: 0.223
# [Epochs: 1/10, Total Batches: 72, Images: 720/2207] loss: 0.240
# [Epochs: 1/10, Total Batches: 73, Images: 730/2207] loss: 0.225
# [Epochs: 1/10, Total Batches: 74, Images: 740/2207] loss: 0.258
# [Epochs: 1/10, Total Batches: 75, Images: 750/2207] loss: 0.258
# [Epochs: 1/10, Total Batches: 76, Images: 760/2207] loss: 0.213
# [Epochs: 1/10, Total Batches: 77, Images: 770/2207] loss: 0.239
# [Epochs: 1/10, Total Batches: 78, Images: 780/2207] loss: 0.249
# [Epochs: 1/10, Total Batches: 79, Images: 790/2207] loss: 0.229
# [Epochs: 1/10, Total Batches: 80, Images: 800/2207] loss: 0.247
# [Epochs: 1/10, Total Batches: 81, Images: 810/2207] loss: 0.219
# [Epochs: 1/10, Total Batches: 82, Images: 820/2207] loss: 0.212
# [Epochs: 1/10, Total Batches: 83, Images: 830/2207] loss: 0.224
# [Epochs: 1/10, Total Batches: 84, Images: 840/2207] loss: 0.228
# [Epochs: 1/10, Total Batches: 85, Images: 850/2207] loss: 0.232
# [Epochs: 1/10, Total Batches: 86, Images: 860/2207] loss: 0.217
# [Epochs: 1/10, Total Batches: 87, Images: 870/2207] loss: 0.199
# [Epochs: 1/10, Total Batches: 88, Images: 880/2207] loss: 0.247
# [Epochs: 1/10, Total Batches: 89, Images: 890/2207] loss: 0.225
# [Epochs: 1/10, Total Batches: 90, Images: 900/2207] loss: 0.228
# [Epochs: 1/10, Total Batches: 91, Images: 910/2207] loss: 0.248
# [Epochs: 1/10, Total Batches: 92, Images: 920/2207] loss: 0.225
# [Epochs: 1/10, Total Batches: 93, Images: 930/2207] loss: 0.195
# [Epochs: 1/10, Total Batches: 94, Images: 940/2207] loss: 0.224
# [Epochs: 1/10, Total Batches: 95, Images: 950/2207] loss: 0.218
# [Epochs: 1/10, Total Batches: 96, Images: 960/2207] loss: 0.228
# [Epochs: 1/10, Total Batches: 97, Images: 970/2207] loss: 0.209
# [Epochs: 1/10, Total Batches: 98, Images: 980/2207] loss: 0.200
# [Epochs: 1/10, Total Batches: 99, Images: 990/2207] loss: 0.209
# [Epochs: 1/10, Total Batches: 100, Images: 1000/2207] loss: 0.219
# [Epochs: 1/10, Total Batches: 101, Images: 1010/2207] loss: 0.197
# [Epochs: 1/10, Total Batches: 102, Images: 1020/2207] loss: 0.230
# [Epochs: 1/10, Total Batches: 103, Images: 1030/2207] loss: 0.197
# [Epochs: 1/10, Total Batches: 104, Images: 1040/2207] loss: 0.203
# [Epochs: 1/10, Total Batches: 105, Images: 1050/2207] loss: 0.224
# [Epochs: 1/10, Total Batches: 106, Images: 1060/2207] loss: 0.216
# [Epochs: 1/10, Total Batches: 107, Images: 1070/2207] loss: 0.219
# [Epochs: 1/10, Total Batches: 108, Images: 1080/2207] loss: 0.211
# [Epochs: 1/10, Total Batches: 109, Images: 1090/2207] loss: 0.203
# [Epochs: 1/10, Total Batches: 110, Images: 1100/2207] loss: 0.213
# [Epochs: 1/10, Total Batches: 111, Images: 1110/2207] loss: 0.213
# [Epochs: 1/10, Total Batches: 112, Images: 1120/2207] loss: 0.191
# [Epochs: 1/10, Total Batches: 113, Images: 1130/2207] loss: 0.224
# [Epochs: 1/10, Total Batches: 114, Images: 1140/2207] loss: 0.207
# [Epochs: 1/10, Total Batches: 115, Images: 1150/2207] loss: 0.203
# [Epochs: 1/10, Total Batches: 116, Images: 1160/2207] loss: 0.224
# [Epochs: 1/10, Total Batches: 117, Images: 1170/2207] loss: 0.210
# [Epochs: 1/10, Total Batches: 118, Images: 1180/2207] loss: 0.195
# [Epochs: 1/10, Total Batches: 119, Images: 1190/2207] loss: 0.209
# [Epochs: 1/10, Total Batches: 120, Images: 1200/2207] loss: 0.199
# [Epochs: 1/10, Total Batches: 121, Images: 1210/2207] loss: 0.198
# [Epochs: 1/10, Total Batches: 122, Images: 1220/2207] loss: 0.189
# [Epochs: 1/10, Total Batches: 123, Images: 1230/2207] loss: 0.207
# [Epochs: 1/10, Total Batches: 124, Images: 1240/2207] loss: 0.200
# [Epochs: 1/10, Total Batches: 125, Images: 1250/2207] loss: 0.214
# [Epochs: 1/10, Total Batches: 126, Images: 1260/2207] loss: 0.198
# [Epochs: 1/10, Total Batches: 127, Images: 1270/2207] loss: 0.185
# [Epochs: 1/10, Total Batches: 128, Images: 1280/2207] loss: 0.179
# [Epochs: 1/10, Total Batches: 129, Images: 1290/2207] loss: 0.201
# [Epochs: 1/10, Total Batches: 130, Images: 1300/2207] loss: 0.196
# [Epochs: 1/10, Total Batches: 131, Images: 1310/2207] loss: 0.179
# [Epochs: 1/10, Total Batches: 132, Images: 1320/2207] loss: 0.205
# [Epochs: 1/10, Total Batches: 133, Images: 1330/2207] loss: 0.193
# [Epochs: 1/10, Total Batches: 134, Images: 1340/2207] loss: 0.209
# [Epochs: 1/10, Total Batches: 135, Images: 1350/2207] loss: 0.178
# [Epochs: 1/10, Total Batches: 136, Images: 1360/2207] loss: 0.199
# [Epochs: 1/10, Total Batches: 137, Images: 1370/2207] loss: 0.184
# [Epochs: 1/10, Total Batches: 138, Images: 1380/2207] loss: 0.202
# [Epochs: 1/10, Total Batches: 139, Images: 1390/2207] loss: 0.184
# [Epochs: 1/10, Total Batches: 140, Images: 1400/2207] loss: 0.183
# [Epochs: 1/10, Total Batches: 141, Images: 1410/2207] loss: 0.191
# [Epochs: 1/10, Total Batches: 142, Images: 1420/2207] loss: 0.197
# [Epochs: 1/10, Total Batches: 143, Images: 1430/2207] loss: 0.185
# [Epochs: 1/10, Total Batches: 144, Images: 1440/2207] loss: 0.196
# [Epochs: 1/10, Total Batches: 145, Images: 1450/2207] loss: 0.198
# [Epochs: 1/10, Total Batches: 146, Images: 1460/2207] loss: 0.181
# [Epochs: 1/10, Total Batches: 147, Images: 1470/2207] loss: 0.176
# [Epochs: 1/10, Total Batches: 148, Images: 1480/2207] loss: 0.171
# [Epochs: 1/10, Total Batches: 149, Images: 1490/2207] loss: 0.188
# [Epochs: 1/10, Total Batches: 150, Images: 1500/2207] loss: 0.203
# [Epochs: 1/10, Total Batches: 151, Images: 1510/2207] loss: 0.189
# [Epochs: 1/10, Total Batches: 152, Images: 1520/2207] loss: 0.186
# [Epochs: 1/10, Total Batches: 153, Images: 1530/2207] loss: 0.189
# [Epochs: 1/10, Total Batches: 154, Images: 1540/2207] loss: 0.189
# [Epochs: 1/10, Total Batches: 155, Images: 1550/2207] loss: 0.191
# [Epochs: 1/10, Total Batches: 156, Images: 1560/2207] loss: 0.165
# [Epochs: 1/10, Total Batches: 157, Images: 1570/2207] loss: 0.188
# [Epochs: 1/10, Total Batches: 158, Images: 1580/2207] loss: 0.193
# [Epochs: 1/10, Total Batches: 159, Images: 1590/2207] loss: 0.177
# [Epochs: 1/10, Total Batches: 160, Images: 1600/2207] loss: 0.201
# [Epochs: 1/10, Total Batches: 161, Images: 1610/2207] loss: 0.181
# [Epochs: 1/10, Total Batches: 162, Images: 1620/2207] loss: 0.173
# [Epochs: 1/10, Total Batches: 163, Images: 1630/2207] loss: 0.188
# [Epochs: 1/10, Total Batches: 164, Images: 1640/2207] loss: 0.162
# [Epochs: 1/10, Total Batches: 165, Images: 1650/2207] loss: 0.171
# [Epochs: 1/10, Total Batches: 166, Images: 1660/2207] loss: 0.181
# [Epochs: 1/10, Total Batches: 167, Images: 1670/2207] loss: 0.178
# [Epochs: 1/10, Total Batches: 168, Images: 1680/2207] loss: 0.175
# [Epochs: 1/10, Total Batches: 169, Images: 1690/2207] loss: 0.172
# [Epochs: 1/10, Total Batches: 170, Images: 1700/2207] loss: 0.167
# [Epochs: 1/10, Total Batches: 171, Images: 1710/2207] loss: 0.184
# [Epochs: 1/10, Total Batches: 172, Images: 1720/2207] loss: 0.180
# [Epochs: 1/10, Total Batches: 173, Images: 1730/2207] loss: 0.179
# [Epochs: 1/10, Total Batches: 174, Images: 1740/2207] loss: 0.182
# [Epochs: 1/10, Total Batches: 175, Images: 1750/2207] loss: 0.179
# [Epochs: 1/10, Total Batches: 176, Images: 1760/2207] loss: 0.184
# [Epochs: 1/10, Total Batches: 177, Images: 1770/2207] loss: 0.188
# [Epochs: 1/10, Total Batches: 178, Images: 1780/2207] loss: 0.169
# [Epochs: 1/10, Total Batches: 179, Images: 1790/2207] loss: 0.169
# [Epochs: 1/10, Total Batches: 180, Images: 1800/2207] loss: 0.162
# [Epochs: 1/10, Total Batches: 181, Images: 1810/2207] loss: 0.152
# [Epochs: 1/10, Total Batches: 182, Images: 1820/2207] loss: 0.171
# [Epochs: 1/10, Total Batches: 183, Images: 1830/2207] loss: 0.182
# [Epochs: 1/10, Total Batches: 184, Images: 1840/2207] loss: 0.171
# [Epochs: 1/10, Total Batches: 185, Images: 1850/2207] loss: 0.184
# [Epochs: 1/10, Total Batches: 186, Images: 1860/2207] loss: 0.164
# [Epochs: 1/10, Total Batches: 187, Images: 1870/2207] loss: 0.163
# [Epochs: 1/10, Total Batches: 188, Images: 1880/2207] loss: 0.169
# [Epochs: 1/10, Total Batches: 189, Images: 1890/2207] loss: 0.173
# [Epochs: 1/10, Total Batches: 190, Images: 1900/2207] loss: 0.168
# [Epochs: 1/10, Total Batches: 191, Images: 1910/2207] loss: 0.178
# [Epochs: 1/10, Total Batches: 192, Images: 1920/2207] loss: 0.162
# [Epochs: 1/10, Total Batches: 193, Images: 1930/2207] loss: 0.166
# [Epochs: 1/10, Total Batches: 194, Images: 1940/2207] loss: 0.178
# [Epochs: 1/10, Total Batches: 195, Images: 1950/2207] loss: 0.170
# [Epochs: 1/10, Total Batches: 196, Images: 1960/2207] loss: 0.176
# [Epochs: 1/10, Total Batches: 197, Images: 1970/2207] loss: 0.157
# [Epochs: 1/10, Total Batches: 198, Images: 1980/2207] loss: 0.159
# [Epochs: 1/10, Total Batches: 199, Images: 1990/2207] loss: 0.163
# [Epochs: 1/10, Total Batches: 200, Images: 2000/2207] loss: 0.174
# [Epochs: 1/10, Total Batches: 201, Images: 2010/2207] loss: 0.166
# [Epochs: 1/10, Total Batches: 202, Images: 2020/2207] loss: 0.162
# [Epochs: 1/10, Total Batches: 203, Images: 2030/2207] loss: 0.162
# [Epochs: 1/10, Total Batches: 204, Images: 2040/2207] loss: 0.151
# [Epochs: 1/10, Total Batches: 205, Images: 2050/2207] loss: 0.154
# [Epochs: 1/10, Total Batches: 206, Images: 2060/2207] loss: 0.163
# [Epochs: 1/10, Total Batches: 207, Images: 2070/2207] loss: 0.174
# [Epochs: 1/10, Total Batches: 208, Images: 2080/2207] loss: 0.150
# [Epochs: 1/10, Total Batches: 209, Images: 2090/2207] loss: 0.168
# [Epochs: 1/10, Total Batches: 210, Images: 2100/2207] loss: 0.169
# [Epochs: 1/10, Total Batches: 211, Images: 2110/2207] loss: 0.158
# [Epochs: 1/10, Total Batches: 212, Images: 2120/2207] loss: 0.157
# [Epochs: 1/10, Total Batches: 213, Images: 2130/2207] loss: 0.173
# [Epochs: 1/10, Total Batches: 214, Images: 2140/2207] loss: 0.151
# [Epochs: 1/10, Total Batches: 215, Images: 2150/2207] loss: 0.148
# [Epochs: 1/10, Total Batches: 216, Images: 2160/2207] loss: 0.160
# [Epochs: 1/10, Total Batches: 217, Images: 2170/2207] loss: 0.167
# [Epochs: 1/10, Total Batches: 218, Images: 2180/2207] loss: 0.159
# [Epochs: 1/10, Total Batches: 219, Images: 2190/2207] loss: 0.158
# [Epochs: 1/10, Total Batches: 220, Images: 2200/2207] loss: 0.149
# [Epochs: 2/10, Total Batches: 221, Images: 10/2207] loss: 0.151
# [Epochs: 2/10, Total Batches: 222, Images: 20/2207] loss: 0.149
# [Epochs: 2/10, Total Batches: 223, Images: 30/2207] loss: 0.158
# [Epochs: 2/10, Total Batches: 224, Images: 40/2207] loss: 0.151
# [Epochs: 2/10, Total Batches: 225, Images: 50/2207] loss: 0.164
# [Epochs: 2/10, Total Batches: 226, Images: 60/2207] loss: 0.155
# [Epochs: 2/10, Total Batches: 227, Images: 70/2207] loss: 0.141
# [Epochs: 2/10, Total Batches: 228, Images: 80/2207] loss: 0.158
# [Epochs: 2/10, Total Batches: 229, Images: 90/2207] loss: 0.148
# [Epochs: 2/10, Total Batches: 230, Images: 100/2207] loss: 0.151
# [Epochs: 2/10, Total Batches: 231, Images: 110/2207] loss: 0.146
# [Epochs: 2/10, Total Batches: 232, Images: 120/2207] loss: 0.143
# [Epochs: 2/10, Total Batches: 233, Images: 130/2207] loss: 0.150
# [Epochs: 2/10, Total Batches: 234, Images: 140/2207] loss: 0.154
# [Epochs: 2/10, Total Batches: 235, Images: 150/2207] loss: 0.151
# [Epochs: 2/10, Total Batches: 236, Images: 160/2207] loss: 0.146
# [Epochs: 2/10, Total Batches: 237, Images: 170/2207] loss: 0.155
# [Epochs: 2/10, Total Batches: 238, Images: 180/2207] loss: 0.150
# [Epochs: 2/10, Total Batches: 239, Images: 190/2207] loss: 0.151
# [Epochs: 2/10, Total Batches: 240, Images: 200/2207] loss: 0.155
# [Epochs: 2/10, Total Batches: 241, Images: 210/2207] loss: 0.146
# [Epochs: 2/10, Total Batches: 242, Images: 220/2207] loss: 0.162
# [Epochs: 2/10, Total Batches: 243, Images: 230/2207] loss: 0.142
# [Epochs: 2/10, Total Batches: 244, Images: 240/2207] loss: 0.146
# [Epochs: 2/10, Total Batches: 245, Images: 250/2207] loss: 0.146
# [Epochs: 2/10, Total Batches: 246, Images: 260/2207] loss: 0.156
# [Epochs: 2/10, Total Batches: 247, Images: 270/2207] loss: 0.143
# [Epochs: 2/10, Total Batches: 248, Images: 280/2207] loss: 0.146
# [Epochs: 2/10, Total Batches: 249, Images: 290/2207] loss: 0.136
# [Epochs: 2/10, Total Batches: 250, Images: 300/2207] loss: 0.152
# [Epochs: 2/10, Total Batches: 251, Images: 310/2207] loss: 0.144
# [Epochs: 2/10, Total Batches: 252, Images: 320/2207] loss: 0.147
# [Epochs: 2/10, Total Batches: 253, Images: 330/2207] loss: 0.170
# [Epochs: 2/10, Total Batches: 254, Images: 340/2207] loss: 0.158
# [Epochs: 2/10, Total Batches: 255, Images: 350/2207] loss: 0.143
# [Epochs: 2/10, Total Batches: 256, Images: 360/2207] loss: 0.159
# [Epochs: 2/10, Total Batches: 257, Images: 370/2207] loss: 0.141
# [Epochs: 2/10, Total Batches: 258, Images: 380/2207] loss: 0.154
# [Epochs: 2/10, Total Batches: 259, Images: 390/2207] loss: 0.158
# [Epochs: 2/10, Total Batches: 260, Images: 400/2207] loss: 0.144
# [Epochs: 2/10, Total Batches: 261, Images: 410/2207] loss: 0.143
# [Epochs: 2/10, Total Batches: 262, Images: 420/2207] loss: 0.144
# [Epochs: 2/10, Total Batches: 263, Images: 430/2207] loss: 0.157
# [Epochs: 2/10, Total Batches: 264, Images: 440/2207] loss: 0.147
# [Epochs: 2/10, Total Batches: 265, Images: 450/2207] loss: 0.150
# [Epochs: 2/10, Total Batches: 266, Images: 460/2207] loss: 0.146
# [Epochs: 2/10, Total Batches: 267, Images: 470/2207] loss: 0.148
# [Epochs: 2/10, Total Batches: 268, Images: 480/2207] loss: 0.148
# [Epochs: 2/10, Total Batches: 269, Images: 490/2207] loss: 0.142
# [Epochs: 2/10, Total Batches: 270, Images: 500/2207] loss: 0.139
# [Epochs: 2/10, Total Batches: 271, Images: 510/2207] loss: 0.135
# [Epochs: 2/10, Total Batches: 272, Images: 520/2207] loss: 0.138
# [Epochs: 2/10, Total Batches: 273, Images: 530/2207] loss: 0.147
# [Epochs: 2/10, Total Batches: 274, Images: 540/2207] loss: 0.146
# [Epochs: 2/10, Total Batches: 275, Images: 550/2207] loss: 0.140
# [Epochs: 2/10, Total Batches: 276, Images: 560/2207] loss: 0.154
# [Epochs: 2/10, Total Batches: 277, Images: 570/2207] loss: 0.148
# [Epochs: 2/10, Total Batches: 278, Images: 580/2207] loss: 0.138
# [Epochs: 2/10, Total Batches: 279, Images: 590/2207] loss: 0.137
# [Epochs: 2/10, Total Batches: 280, Images: 600/2207] loss: 0.147
# [Epochs: 2/10, Total Batches: 281, Images: 610/2207] loss: 0.137

# %%
writer.close()
